# %% [markdown]
# # Session 05: Getting data from APIs
#
# In this session, we will learn how to get data from APIs.
#
# ## What is an API?
#
# API stands for Application Programming Interface. It is a set of rules that allows one software application to interact with another. APIs are used to define the methods for communication between different software components.
#
# There are several types of APIs, such as web APIs, library APIs, and operating system APIs. In this session, we will focus on web APIs. Web APIs are used to enable communication between different software applications over the internet. We can use web APIs to get data from external sources, such as weather data, stock prices, and social media posts.
#
# In order to use a web API, we need to send a request to the API server and receive a response. The request is usually sent in the form of a URL, and the response is usually in the form of JSON or XML data.
#
# Types of requests:
# - `GET`: Retrieve data from the server.
# - `POST`: Send data to the server.
# - `PUT`: Update data on the server.
# - `DELETE`: Delete data from the server.
#
# Types of responses:
# - JSON: JavaScript Object Notation.
# - XML: Extensible Markup Language.
#
# Status codes:
# - `200`: OK.
# - `400`: Bad request.
# - `401`: Unauthorized.
# - `404`: Not found.
# - `500`: Internal server error.
#
# We are going to focus on the `GET` request and JSON response in this session.
#
# ## Getting access to an API
#
# We will use the ESIOS API to get power market data from the Spanish electricity market.
#
# * [ESIOS API](https://api.esios.ree.es/)
#
# You will need to request an API key to access the ESIOS API. You can request an API key sending an email to the following address: `consultasios@ree.es` with the subject `Personal token request`. Mention that you are a student and you are using the API for educational purposes.

# %% [markdown]
# ## Making a request to the API
#
# Once you've received your token, we can start making requests to the ESIOS API. We will use the `requests` library in Python to make HTTP requests to the API server.
#
# But first we need to load the token from the `.env` file.

# %%
# load environment variables from the .env file
import os
from dotenv import load_dotenv

load_dotenv()

# get the API token from the environment variables
api_token = os.getenv('API_KEY_PYTHON_CLASS')
api_token[:5]
# Out:
# '3fdd9'

# %% [markdown]
# Now we need to install the `requests` library.
#
# ```bash
# !pip install requests
# ```
#
# Now we are ready to make a request to the ESIOS API. You can read the documentation of the API to understand how to make requests and what data you can get.
#
# For now, we will focus on some examples that I will show you.

# %% [markdown]
# ## Example 1: Get the list of available indicators
#
# The first example is to get the list of available indicators from the ESIOS API.
#
# These indicators represent different types of data that we can get from the API, such as electricity prices, demand, generation, etc.
#
# Let's make a request to the API to get the list of available indicators as a JSON response, and then save the response to a file.
#
# Documentation: [ESIOS API - Getting a list of indicators](https://api.esios.ree.es/doc/indicator/getting_a_list_of_indicators.html)

# %%
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\users\slo\appdata\roaming\python\python38\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\slo\appdata\roaming\python\python38\site-packages (from requests) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\slo\appdata\roaming\python\python38\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\slo\appdata\roaming\python\python38\site-packages (from requests) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\slo\appdata\roaming\python\python38\site-packages (from requests) (2023.7.22)

# %%
import requests
import pandas as pd

# the API endpoint
url = 'https://api.esios.ree.es/indicators'

# define the headers
headers = {
    'Accept': 'application/json; application/vnd.esios-api-v1+json',
    'Content-Type': 'application/json',
    'x-api-key': f'{api_token}'
}

# Make the GET request
response = requests.get(url, headers=headers)
response_json = response.json()

# check if the response is successful
if response.status_code != 200:
    print(f'Error: {response_json["error"]}')
else:

    # make a directory to store the data if it doesn't exist
    if not os.path.exists('./data'):
        os.makedirs('./data')

    # save the response content to a CSV file
    indicators = response_json['indicators']
    df = pd.DataFrame(indicators)
    df.to_csv('./data/indicators.csv', index=False)

# %% [markdown]
# ## Example 2: Understanding the indicators
#
# The second example is to get the id of a specific indicator from the ESIOS API. We are going to read the list of available indicators from the file that we saved in the previous example, and then select an indicator id.

# %%
# reading the data from the CSV file

indicators = pd.read_csv('./data/indicators.csv')

indicators.head()
# Out:
#                                                 name  \
# 0           Generación programada PBF Hidráulica UGH
# 1        Generación programada PBF Hidráulica no UGH
# 2       Generación programada PBF Turbinación bombeo
# 3                  Generación programada PBF Nuclear
# 4  Generación programada PBF Hulla antracita Anex...
#
#                                          description  \
# 0  <p>Es el programa de energía diario, con desgl...
# 1  <p>Es el programa de energía diario, con desgl...
# 2  <p>Es el programa de energía diario, con desgl...
# 3  <p>Es el programa de energía diario, con desgl...
# 4  <p>Es el programa de energía diario, con desgl...
#
#                     short_name  id
# 0               Hidráulica UGH   1
# 1            Hidráulica no UGH   2
# 2           Turbinación bombeo   3
# 3                      Nuclear   4
# 4  Hulla antracita RD 134/2010   5

# %% [markdown]
# Let's sweep throught he list of available indicators looking for all the indicators that contain the word `Previsión` (forecast in spanish) in their name. We will use the `str.contains` method from pandas to filter the indicators.

# %%
# looking for `Previsión` or `prevista` in the `name` column (it means forecast in Spanish)

prevision_indicators = indicators[indicators['name'].str.contains('Previsión', case=False)]
prevista_indicators = indicators[indicators['name'].str.contains('prevista', case=False)]

# %%
prevision_indicators
# Out:
#                                                    name  \
# 459   Previsión diaria de la demanda eléctrica penin...
# 460   Previsión mensual de la demanda eléctrica peni...
# 538        Previsión de la producción eólica peninsular
# 576   Previsión semanal de la demanda eléctrica peni...
# 577   Previsión máxima mensual de la demanda eléctri...
# 592   Previsión mínima mensual de la demanda eléctri...
# 593   Previsión máxima anual de la demanda eléctrica...
# 594   Previsión mínima anual de la demanda eléctrica...
# 1427                            Previsión demanda anual
# 1428                       Previsión diaria D+1 demanda
# 1429                  Previsión intradiaria H+3 demanda
# 1430                        Previsión diaria D+1 eólica
# 1431                   Previsión intradiaria H+3 eólica
# 1432                  Previsión diaria D+1 fotovoltaica
# 1433             Previsión intradiaria H+3 fotovoltaica
# 1873                   Previsión de la demanda residual
# 1935       Previsión diaria D+1 eólica más fotovoltaica
# 1936  Previsión intradiaria H+3 eólica más fotovoltaica
#
#                                             description  \
# 459   \r\n\r\n<p>Es la previsi&oacute;n de consumo q...
# 460   <p>Previsi&oacute;n de la demanda del sistema ...
# 538   <p>Previsi&oacute;n horaria de energ&iacute;a ...
# 576   <p>Previsión de la demanda del sistema peninsu...
# 577   <p>Previsión de la demanda del sistema peninsu...
# 592   <p>Previsión de la demanda del sistema peninsu...
# 593   <p>Previsión de la demanda del sistema peninsu...
# 594   <p>Previsión de la demanda del sistema peninsu...
# 1427  <p>La Circular 4/2019 de la CNMC por la que se...
# 1428  <p>La Circular 4/2019 de la CNMC por la que se...
# 1429  <p>La Circular 4/2019 de la CNMC por la que se...
# 1430  <p>Este indicador corresponde a la predicci&oa...
# 1431  <p>Este indicador corresponde a la predicci&oa...
# 1432  <p>Este indicador corresponde a la predicci&oa...
# 1433  <p>Este indicador corresponde a la predicci&oa...
# 1873  <p>Previsión resultante de restar a la previsi...
# 1935  <p>La Circular 4/2019 de la CNMC por la que se...
# 1936  <p>La Circular 4/2019 de la CNMC por la que se...
#
#                                              short_name     id
# 459                                    Previsión diaria    460
# 460                                   Previsión mensual    461
# 538                                    Previsión eólica    541
# 576                                   Previsión semanal    603
# 577                            Previsión máxima mensual    604
# 592                            Previsión mínima mensual    619
# 593                              Previsión máxima anual    620
# 594                              Previsión mínima anual    621
# 1427                                      Demanda anual   1774
# 1428                       Previsión diaria D+1 demanda   1775
# 1429                  Previsión intradiaria H+3 demanda   1776
# 1430                        Previsión diaria D+1 eólica   1777
# 1431                   Previsión intradiaria H+3 eólica   1778
# 1432                  Previsión diaria D+1 fotovoltaica   1779
# 1433             Previsión intradiaria H+3 fotovoltaica   1780
# 1873                         Previsión demanda residual  10249
# 1935       Previsión diaria D+1 eólica más fotovoltaica  10358
# 1936  Previsión intradiaria H+3 eólica más fotovoltaica  10359

# %%
prevista_indicators
# Out:
#                                                    name  \
# 497   Capacidad de intercambio prevista (NTC) con Fr...
# 498   Capacidad de intercambio prevista (NTC) con Po...
# 499   Capacidad de intercambio prevista (NTC) con Ma...
# 500   Capacidad de intercambio prevista (NTC) con An...
# 501   Capacidad de intercambio prevista (NTC) con Fr...
# 502   Capacidad de intercambio prevista (NTC) con Po...
# 503   Capacidad de intercambio prevista (NTC) con Ma...
# 504   Capacidad de intercambio prevista (NTC) con An...
# 507   Capacidad de intercambio prevista (NTC) con Fr...
# 508   Capacidad de intercambio prevista (NTC) con Po...
# 509   Capacidad de intercambio prevista (NTC) con Ma...
# 510   Capacidad de intercambio prevista (NTC) con An...
# 511   Capacidad de intercambio prevista (NTC) con Fr...
# 512   Capacidad de intercambio prevista (NTC) con Po...
# 513   Capacidad de intercambio prevista (NTC) con Ma...
# 514   Capacidad de intercambio prevista (NTC) con An...
# 515   Capacidad de intercambio prevista (NTC) con Fr...
# 516   Capacidad de intercambio prevista (NTC) con Po...
# 517   Capacidad de intercambio prevista (NTC) con Ma...
# 518   Capacidad de intercambio prevista (NTC) con An...
# 519   Capacidad de intercambio prevista (NTC) con Fr...
# 520   Capacidad de intercambio prevista (NTC) con Po...
# 521   Capacidad de intercambio prevista (NTC) con Ma...
# 522   Capacidad de intercambio prevista (NTC) con An...
# 539              Generación prevista Solar fotovoltaica
# 540                   Generación prevista Solar térmica
# 541                                    Demanda prevista
# 567   Capacidad prevista en el enlace Península - Ba...
# 595   Margen generación disponible - máxima demanda ...
# 1411                               Demanda prevista SNP
# 1489  Capacidad de intercambio prevista (NTC) con Fr...
# 1490  Capacidad de intercambio prevista (NTC) con Po...
# 1491  Capacidad de intercambio prevista (NTC) con Ma...
# 1492  Capacidad de intercambio prevista (NTC) con Fr...
# 1493  Capacidad de intercambio prevista (NTC) con Po...
# 1494  Capacidad de intercambio prevista (NTC) con Ma...
# 1570                     Demanda real prevista nacional
# 1592  Demanda prevista nacional para sistemas no pen...
# 1610  Capacidad de intercambio comercial prevista en...
# 1611  Capacidad de intercambio comercial prevista en...
# 1612  Capacidad de intercambio comercial prevista en...
# 1613  Capacidad de intercambio comercial prevista en...
# 1666                          Generación prevista Solar
#
#                                             description  \
# 497   <p>M&aacute;ximo valor admisible del programa ...
# 498   <p>M&aacute;ximo valor admisible del programa ...
# 499   <p>M&aacute;ximo valor admisible del programa ...
# 500   <p>M&aacute;ximo valor admisible del programa ...
# 501   <p>M&aacute;ximo valor admisible del programa ...
# 502   <p>M&aacute;ximo valor admisible del programa ...
# 503   <p>M&aacute;ximo valor admisible del programa ...
# 504   <p>M&aacute;ximo valor admisible del programa ...
# 507   <p>M&aacute;ximo valor admisible del programa ...
# 508   <p>M&aacute;ximo valor admisible del programa ...
# 509   <p>M&aacute;ximo valor admisible del programa ...
# 510   <p>M&aacute;ximo valor admisible del programa ...
# 511   <p>M&aacute;ximo valor admisible del programa ...
# 512   <p>M&aacute;ximo valor admisible del programa ...
# 513   <p>M&aacute;ximo valor admisible del programa ...
# 514   <p>M&aacute;ximo valor admisible del programa ...
# 515   <p>M&aacute;ximo valor admisible del programa ...
# 516   <p>M&aacute;ximo valor admisible del programa ...
# 517   <p>M&aacute;ximo valor admisible del programa ...
# 518   <p>M&aacute;ximo valor admisible del programa ...
# 519   <p>M&aacute;ximo valor admisible del programa ...
# 520   <p>M&aacute;ximo valor admisible del programa ...
# 521   <p>M&aacute;ximo valor admisible del programa ...
# 522   <p>M&aacute;ximo valor admisible del programa ...
# 539   <p>Previsión horaria de generación de energía ...
# 540   <p>Previsión horaria de generación de energía ...
# 541   \r\n\r\n<p>Es la previsi&oacute;n de consumo q...
# 567   <p>Es la capacidad disponible en el enlace HVD...
# 595   <p>Resta de la previsión de generación disponi...
# 1411  <p>Es la previsi&oacute;n de consumo de los si...
# 1489  <p>M&aacute;ximo valor admisible del programa ...
# 1490  <p>M&aacute;ximo valor admisible del programa ...
# 1491  <p>M&aacute;ximo valor admisible del programa ...
# 1492  <p>M&aacute;ximo valor admisible del programa ...
# 1493  <p>M&aacute;ximo valor admisible del programa ...
# 1494  <p>M&aacute;ximo valor admisible del programa ...
# 1570                                                NaN
# 1592  <p>Demanda prevista a nivel nacional para los ...
# 1610  <p>M&aacute;ximo valor admisible del programa ...
# 1611  <p>M&aacute;ximo valor admisible del programa ...
# 1612  <p>M&aacute;ximo valor admisible del programa ...
# 1613  <p>M&aacute;ximo valor admisible del programa ...
# 1666  <p>Previsión horaria de generación de energía ...
#
#                                              short_name     id
# 497               Francia horizonte semanal importación    498
# 498              Portugal horizonte semanal importación    499
# 499             Marruecos horizonte semanal importación    500
# 500               Andorra horizonte semanal importación    501
# 501               Francia horizonte semanal exportación    502
# 502              Portugal horizonte semanal exportación    503
# 503             Marruecos horizonte semanal exportación    504
# 504               Andorra horizonte semanal exportación    505
# 507               Francia horizonte mensual importación    510
# 508              Portugal horizonte mensual importación    511
# 509             Marruecos horizonte mensual importación    512
# 510               Andorra horizonte mensual importación    513
# 511               Francia horizonte mensual exportación    514
# 512              Portugal horizonte mensual exportación    515
# 513             Marruecos horizonte mensual exportación    516
# 514               Andorra horizonte mensual exportación    517
# 515                 Francia horizonte anual importación    518
# 516                Portugal horizonte anual importación    519
# 517               Marruecos horizonte anual importación    520
# 518                 Andorra horizonte anual importación    521
# 519                 Francia horizonte anual exportación    522
# 520                Portugal horizonte anual exportación    523
# 521               Marruecos horizonte anual exportación    524
# 522                 Andorra horizonte anual exportación    525
# 539                                  Solar fotovoltaica    542
# 540                                       Solar térmica    543
# 541                                    Demanda prevista    544
# 567                                  Península-Baleares    570
# 595               G. Disponible - Máx. Demanda prevista    622
# 1411                               Demanda prevista SNP   1742
# 1489               Francia horizonte diario importación   1844
# 1490              Portugal horizonte diario importación   1845
# 1491             Marruecos horizonte diario importación   1846
# 1492               Francia horizonte diario exportación   1848
# 1493              Portugal horizonte diario exportación   1849
# 1494             Marruecos horizonte diario exportación   1850
# 1570                     Demanda real prevista nacional   2052
# 1592  Demanda prevista nacional para sistemas no pen...   2084
# 1610          Francia horizonte intradiario importación   2117
# 1611          Francia horizonte intradiario exportación   2118
# 1612         Portugal horizonte intradiario importación   2119
# 1613         Portugal horizonte intradiario exportación   2120
# 1666                                    Previsión solar  10034

# %% [markdown]
# There seems to be 2 indicators for forecasted demand, let's get the data for both and compare.
#
# * Indicator 460
# * Indicator 544

# %% [markdown]
# ## Example 3: Get the data for an indicator
#
# The third example is to get the data for a specific indicator from the ESIOS API. We are going to use the indicator id that we selected in the previous example to get the data for that indicator between two dates.
#
# We will check the forecasted demand for Christmas' Eve.
#
# Documentation: [ESIOS API - Getting the data for an indicator between two dates](https://api.esios.ree.es/doc/indicator/getting_a_specific_indicator_filtering_values_by_a_date_range.html)

# %%
indicator_id = 460

# when we want to get the data for a specific date range, we need to provide the start and end date
# in the ISO 8601 format: YYYY-MM-DDTHH:MM:SSZ
# since the hour in Spain is UTC+1 in winter and UTC+2 in summer, we need to adjust the hour
start_date = '2025-01-23T23:00:00Z' 
end_date = '2025-12-24T22:59:59Z'

# the API endpoint
url = f'https://api.esios.ree.es/indicators/{indicator_id}'

# define the headers
headers = {
    'Accept': 'application/json; application/vnd.esios-api-v1+json',
    'Content-Type': 'application/json',
    'x-api-key': f'{api_token}'
}

# define the parameters, in our case the start and end date
params = {
    'start_date': start_date,
    'end_date': end_date
}

# Make the GET request
response = requests.get(url, headers=headers, params=params)
response_json = response.json()

# %%
response_json
# Out:
# {'indicator': {'name': 'Previsión diaria de la demanda eléctrica peninsular',
#   'short_name': 'Previsión diaria',
#   'id': 460,
#   'composited': False,
#   'step_type': 'step',
#   'disaggregated': False,
#   'magnitud': [{'name': 'Potencia', 'id': 20}],
#   'tiempo': [{'name': 'Quince minutos', 'id': 218}],
#   'geos': [{'geo_id': 8741, 'geo_name': 'Península'}],
#   'values_updated_at': '2025-01-23T18:28:38.000+01:00',
#   'values': [{'value': 26779.0,
#     'datetime': '2025-01-24T00:00:00.000+01:00',
#     'datetime_utc': '2025-01-23T23:00:00Z',
#     'tz_time': '2025-01-23T23:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 26341.0,
#     'datetime': '2025-01-24T00:15:00.000+01:00',
#     'datetime_utc': '2025-01-23T23:15:00Z',
#     'tz_time': '2025-01-23T23:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 25898.0,
#     'datetime': '2025-01-24T00:30:00.000+01:00',
#     'datetime_utc': '2025-01-23T23:30:00Z',
#     'tz_time': '2025-01-23T23:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 25456.0,
#     'datetime': '2025-01-24T00:45:00.000+01:00',
#     'datetime_utc': '2025-01-23T23:45:00Z',
#     'tz_time': '2025-01-23T23:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 24980.0,
#     'datetime': '2025-01-24T01:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T00:00:00Z',
#     'tz_time': '2025-01-24T00:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 24579.0,
#     'datetime': '2025-01-24T01:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T00:15:00Z',
#     'tz_time': '2025-01-24T00:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 24215.0,
#     'datetime': '2025-01-24T01:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T00:30:00Z',
#     'tz_time': '2025-01-24T00:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 23894.0,
#     'datetime': '2025-01-24T01:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T00:45:00Z',
#     'tz_time': '2025-01-24T00:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 23530.0,
#     'datetime': '2025-01-24T02:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T01:00:00Z',
#     'tz_time': '2025-01-24T01:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 23301.0,
#     'datetime': '2025-01-24T02:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T01:15:00Z',
#     'tz_time': '2025-01-24T01:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 23120.0,
#     'datetime': '2025-01-24T02:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T01:30:00Z',
#     'tz_time': '2025-01-24T01:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22981.0,
#     'datetime': '2025-01-24T02:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T01:45:00Z',
#     'tz_time': '2025-01-24T01:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22825.0,
#     'datetime': '2025-01-24T03:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T02:00:00Z',
#     'tz_time': '2025-01-24T02:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22752.0,
#     'datetime': '2025-01-24T03:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T02:15:00Z',
#     'tz_time': '2025-01-24T02:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22703.0,
#     'datetime': '2025-01-24T03:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T02:30:00Z',
#     'tz_time': '2025-01-24T02:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22678.0,
#     'datetime': '2025-01-24T03:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T02:45:00Z',
#     'tz_time': '2025-01-24T02:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22616.0,
#     'datetime': '2025-01-24T04:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T03:00:00Z',
#     'tz_time': '2025-01-24T03:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22637.0,
#     'datetime': '2025-01-24T04:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T03:15:00Z',
#     'tz_time': '2025-01-24T03:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22686.0,
#     'datetime': '2025-01-24T04:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T03:30:00Z',
#     'tz_time': '2025-01-24T03:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22795.0,
#     'datetime': '2025-01-24T04:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T03:45:00Z',
#     'tz_time': '2025-01-24T03:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22729.0,
#     'datetime': '2025-01-24T05:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T04:00:00Z',
#     'tz_time': '2025-01-24T04:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 23058.0,
#     'datetime': '2025-01-24T05:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T04:15:00Z',
#     'tz_time': '2025-01-24T04:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 23545.0,
#     'datetime': '2025-01-24T05:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T04:30:00Z',
#     'tz_time': '2025-01-24T04:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 24187.0,
#     'datetime': '2025-01-24T05:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T04:45:00Z',
#     'tz_time': '2025-01-24T04:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 24784.0,
#     'datetime': '2025-01-24T06:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T05:00:00Z',
#     'tz_time': '2025-01-24T05:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 25703.0,
#     'datetime': '2025-01-24T06:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T05:15:00Z',
#     'tz_time': '2025-01-24T05:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 26737.0,
#     'datetime': '2025-01-24T06:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T05:30:00Z',
#     'tz_time': '2025-01-24T05:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27825.0,
#     'datetime': '2025-01-24T06:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T05:45:00Z',
#     'tz_time': '2025-01-24T05:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 29199.0,
#     'datetime': '2025-01-24T07:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T06:00:00Z',
#     'tz_time': '2025-01-24T06:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30180.0,
#     'datetime': '2025-01-24T07:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T06:15:00Z',
#     'tz_time': '2025-01-24T06:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31004.0,
#     'datetime': '2025-01-24T07:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T06:30:00Z',
#     'tz_time': '2025-01-24T06:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31665.0,
#     'datetime': '2025-01-24T07:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T06:45:00Z',
#     'tz_time': '2025-01-24T06:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32473.0,
#     'datetime': '2025-01-24T08:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T07:00:00Z',
#     'tz_time': '2025-01-24T07:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32838.0,
#     'datetime': '2025-01-24T08:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T07:15:00Z',
#     'tz_time': '2025-01-24T07:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33068.0,
#     'datetime': '2025-01-24T08:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T07:30:00Z',
#     'tz_time': '2025-01-24T07:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33186.0,
#     'datetime': '2025-01-24T08:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T07:45:00Z',
#     'tz_time': '2025-01-24T07:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33322.0,
#     'datetime': '2025-01-24T09:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T08:00:00Z',
#     'tz_time': '2025-01-24T08:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33295.0,
#     'datetime': '2025-01-24T09:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T08:15:00Z',
#     'tz_time': '2025-01-24T08:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33229.0,
#     'datetime': '2025-01-24T09:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T08:30:00Z',
#     'tz_time': '2025-01-24T08:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33130.0,
#     'datetime': '2025-01-24T09:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T08:45:00Z',
#     'tz_time': '2025-01-24T08:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33055.0,
#     'datetime': '2025-01-24T10:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T09:00:00Z',
#     'tz_time': '2025-01-24T09:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32893.0,
#     'datetime': '2025-01-24T10:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T09:15:00Z',
#     'tz_time': '2025-01-24T09:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32704.0,
#     'datetime': '2025-01-24T10:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T09:30:00Z',
#     'tz_time': '2025-01-24T09:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32499.0,
#     'datetime': '2025-01-24T10:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T09:45:00Z',
#     'tz_time': '2025-01-24T09:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32261.0,
#     'datetime': '2025-01-24T11:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T10:00:00Z',
#     'tz_time': '2025-01-24T10:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32070.0,
#     'datetime': '2025-01-24T11:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T10:15:00Z',
#     'tz_time': '2025-01-24T10:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31905.0,
#     'datetime': '2025-01-24T11:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T10:30:00Z',
#     'tz_time': '2025-01-24T10:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31765.0,
#     'datetime': '2025-01-24T11:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T10:45:00Z',
#     'tz_time': '2025-01-24T10:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31614.0,
#     'datetime': '2025-01-24T12:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T11:00:00Z',
#     'tz_time': '2025-01-24T11:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31514.0,
#     'datetime': '2025-01-24T12:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T11:15:00Z',
#     'tz_time': '2025-01-24T11:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31428.0,
#     'datetime': '2025-01-24T12:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T11:30:00Z',
#     'tz_time': '2025-01-24T11:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31351.0,
#     'datetime': '2025-01-24T12:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T11:45:00Z',
#     'tz_time': '2025-01-24T11:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31286.0,
#     'datetime': '2025-01-24T13:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T12:00:00Z',
#     'tz_time': '2025-01-24T12:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31213.0,
#     'datetime': '2025-01-24T13:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T12:15:00Z',
#     'tz_time': '2025-01-24T12:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31133.0,
#     'datetime': '2025-01-24T13:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T12:30:00Z',
#     'tz_time': '2025-01-24T12:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31043.0,
#     'datetime': '2025-01-24T13:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T12:45:00Z',
#     'tz_time': '2025-01-24T12:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30974.0,
#     'datetime': '2025-01-24T14:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T13:00:00Z',
#     'tz_time': '2025-01-24T13:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30849.0,
#     'datetime': '2025-01-24T14:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T13:15:00Z',
#     'tz_time': '2025-01-24T13:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30703.0,
#     'datetime': '2025-01-24T14:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T13:30:00Z',
#     'tz_time': '2025-01-24T13:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30552.0,
#     'datetime': '2025-01-24T14:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T13:45:00Z',
#     'tz_time': '2025-01-24T13:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30342.0,
#     'datetime': '2025-01-24T15:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T14:00:00Z',
#     'tz_time': '2025-01-24T14:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30238.0,
#     'datetime': '2025-01-24T15:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T14:15:00Z',
#     'tz_time': '2025-01-24T14:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30181.0,
#     'datetime': '2025-01-24T15:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T14:30:00Z',
#     'tz_time': '2025-01-24T14:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30171.0,
#     'datetime': '2025-01-24T15:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T14:45:00Z',
#     'tz_time': '2025-01-24T14:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30124.0,
#     'datetime': '2025-01-24T16:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T15:00:00Z',
#     'tz_time': '2025-01-24T15:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30197.0,
#     'datetime': '2025-01-24T16:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T15:15:00Z',
#     'tz_time': '2025-01-24T15:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30310.0,
#     'datetime': '2025-01-24T16:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T15:30:00Z',
#     'tz_time': '2025-01-24T15:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30469.0,
#     'datetime': '2025-01-24T16:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T15:45:00Z',
#     'tz_time': '2025-01-24T15:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30560.0,
#     'datetime': '2025-01-24T17:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T16:00:00Z',
#     'tz_time': '2025-01-24T16:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30845.0,
#     'datetime': '2025-01-24T17:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T16:15:00Z',
#     'tz_time': '2025-01-24T16:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31203.0,
#     'datetime': '2025-01-24T17:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T16:30:00Z',
#     'tz_time': '2025-01-24T16:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31602.0,
#     'datetime': '2025-01-24T17:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T16:45:00Z',
#     'tz_time': '2025-01-24T16:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32098.0,
#     'datetime': '2025-01-24T18:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T17:00:00Z',
#     'tz_time': '2025-01-24T17:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32468.0,
#     'datetime': '2025-01-24T18:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T17:15:00Z',
#     'tz_time': '2025-01-24T17:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32774.0,
#     'datetime': '2025-01-24T18:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T17:30:00Z',
#     'tz_time': '2025-01-24T17:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33025.0,
#     'datetime': '2025-01-24T18:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T17:45:00Z',
#     'tz_time': '2025-01-24T17:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33279.0,
#     'datetime': '2025-01-24T19:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T18:00:00Z',
#     'tz_time': '2025-01-24T18:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33470.0,
#     'datetime': '2025-01-24T19:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T18:15:00Z',
#     'tz_time': '2025-01-24T18:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33654.0,
#     'datetime': '2025-01-24T19:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T18:30:00Z',
#     'tz_time': '2025-01-24T18:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33824.0,
#     'datetime': '2025-01-24T19:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T18:45:00Z',
#     'tz_time': '2025-01-24T18:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 34061.0,
#     'datetime': '2025-01-24T20:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T19:00:00Z',
#     'tz_time': '2025-01-24T19:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 34176.0,
#     'datetime': '2025-01-24T20:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T19:15:00Z',
#     'tz_time': '2025-01-24T19:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 34243.0,
#     'datetime': '2025-01-24T20:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T19:30:00Z',
#     'tz_time': '2025-01-24T19:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 34215.0,
#     'datetime': '2025-01-24T20:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T19:45:00Z',
#     'tz_time': '2025-01-24T19:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 34454.0,
#     'datetime': '2025-01-24T21:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T20:00:00Z',
#     'tz_time': '2025-01-24T20:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 34071.0,
#     'datetime': '2025-01-24T21:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T20:15:00Z',
#     'tz_time': '2025-01-24T20:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33451.0,
#     'datetime': '2025-01-24T21:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T20:30:00Z',
#     'tz_time': '2025-01-24T20:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32655.0,
#     'datetime': '2025-01-24T21:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T20:45:00Z',
#     'tz_time': '2025-01-24T20:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31778.0,
#     'datetime': '2025-01-24T22:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T21:00:00Z',
#     'tz_time': '2025-01-24T21:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30875.0,
#     'datetime': '2025-01-24T22:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T21:15:00Z',
#     'tz_time': '2025-01-24T21:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30030.0,
#     'datetime': '2025-01-24T22:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T21:30:00Z',
#     'tz_time': '2025-01-24T21:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 29268.0,
#     'datetime': '2025-01-24T22:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T21:45:00Z',
#     'tz_time': '2025-01-24T21:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 28422.0,
#     'datetime': '2025-01-24T23:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T22:00:00Z',
#     'tz_time': '2025-01-24T22:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27867.0,
#     'datetime': '2025-01-24T23:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T22:15:00Z',
#     'tz_time': '2025-01-24T22:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27423.0,
#     'datetime': '2025-01-24T23:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T22:30:00Z',
#     'tz_time': '2025-01-24T22:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27054.0,
#     'datetime': '2025-01-24T23:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T22:45:00Z',
#     'tz_time': '2025-01-24T22:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 26774.0,
#     'datetime': '2025-01-25T00:00:00.000+01:00',
#     'datetime_utc': '2025-01-24T23:00:00Z',
#     'tz_time': '2025-01-24T23:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 26420.0,
#     'datetime': '2025-01-25T00:15:00.000+01:00',
#     'datetime_utc': '2025-01-24T23:15:00Z',
#     'tz_time': '2025-01-24T23:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 26017.0,
#     'datetime': '2025-01-25T00:30:00.000+01:00',
#     'datetime_utc': '2025-01-24T23:30:00Z',
#     'tz_time': '2025-01-24T23:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 25573.0,
#     'datetime': '2025-01-25T00:45:00.000+01:00',
#     'datetime_utc': '2025-01-24T23:45:00Z',
#     'tz_time': '2025-01-24T23:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 25111.0,
#     'datetime': '2025-01-25T01:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T00:00:00Z',
#     'tz_time': '2025-01-25T00:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 24647.0,
#     'datetime': '2025-01-25T01:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T00:15:00Z',
#     'tz_time': '2025-01-25T00:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 24202.0,
#     'datetime': '2025-01-25T01:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T00:30:00Z',
#     'tz_time': '2025-01-25T00:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 23790.0,
#     'datetime': '2025-01-25T01:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T00:45:00Z',
#     'tz_time': '2025-01-25T00:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 23312.0,
#     'datetime': '2025-01-25T02:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T01:00:00Z',
#     'tz_time': '2025-01-25T01:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 23009.0,
#     'datetime': '2025-01-25T02:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T01:15:00Z',
#     'tz_time': '2025-01-25T01:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22775.0,
#     'datetime': '2025-01-25T02:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T01:30:00Z',
#     'tz_time': '2025-01-25T01:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22597.0,
#     'datetime': '2025-01-25T02:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T01:45:00Z',
#     'tz_time': '2025-01-25T01:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22427.0,
#     'datetime': '2025-01-25T03:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T02:00:00Z',
#     'tz_time': '2025-01-25T02:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22308.0,
#     'datetime': '2025-01-25T03:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T02:15:00Z',
#     'tz_time': '2025-01-25T02:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22196.0,
#     'datetime': '2025-01-25T03:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T02:30:00Z',
#     'tz_time': '2025-01-25T02:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22093.0,
#     'datetime': '2025-01-25T03:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T02:45:00Z',
#     'tz_time': '2025-01-25T02:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 21959.0,
#     'datetime': '2025-01-25T04:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T03:00:00Z',
#     'tz_time': '2025-01-25T03:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 21892.0,
#     'datetime': '2025-01-25T04:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T03:15:00Z',
#     'tz_time': '2025-01-25T03:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 21852.0,
#     'datetime': '2025-01-25T04:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T03:30:00Z',
#     'tz_time': '2025-01-25T03:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 21845.0,
#     'datetime': '2025-01-25T04:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T03:45:00Z',
#     'tz_time': '2025-01-25T03:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 21785.0,
#     'datetime': '2025-01-25T05:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T04:00:00Z',
#     'tz_time': '2025-01-25T04:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 21859.0,
#     'datetime': '2025-01-25T05:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T04:15:00Z',
#     'tz_time': '2025-01-25T04:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 21981.0,
#     'datetime': '2025-01-25T05:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T04:30:00Z',
#     'tz_time': '2025-01-25T04:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22155.0,
#     'datetime': '2025-01-25T05:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T04:45:00Z',
#     'tz_time': '2025-01-25T04:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22274.0,
#     'datetime': '2025-01-25T06:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T05:00:00Z',
#     'tz_time': '2025-01-25T05:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22564.0,
#     'datetime': '2025-01-25T06:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T05:15:00Z',
#     'tz_time': '2025-01-25T05:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22915.0,
#     'datetime': '2025-01-25T06:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T05:30:00Z',
#     'tz_time': '2025-01-25T05:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 23311.0,
#     'datetime': '2025-01-25T06:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T05:45:00Z',
#     'tz_time': '2025-01-25T05:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 23744.0,
#     'datetime': '2025-01-25T07:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T06:00:00Z',
#     'tz_time': '2025-01-25T06:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 24169.0,
#     'datetime': '2025-01-25T07:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T06:15:00Z',
#     'tz_time': '2025-01-25T06:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 24583.0,
#     'datetime': '2025-01-25T07:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T06:30:00Z',
#     'tz_time': '2025-01-25T06:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 24991.0,
#     'datetime': '2025-01-25T07:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T06:45:00Z',
#     'tz_time': '2025-01-25T06:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 25393.0,
#     'datetime': '2025-01-25T08:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T07:00:00Z',
#     'tz_time': '2025-01-25T07:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 25819.0,
#     'datetime': '2025-01-25T08:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T07:15:00Z',
#     'tz_time': '2025-01-25T07:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 26264.0,
#     'datetime': '2025-01-25T08:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T07:30:00Z',
#     'tz_time': '2025-01-25T07:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 26709.0,
#     'datetime': '2025-01-25T08:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T07:45:00Z',
#     'tz_time': '2025-01-25T07:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27250.0,
#     'datetime': '2025-01-25T09:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T08:00:00Z',
#     'tz_time': '2025-01-25T08:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27630.0,
#     'datetime': '2025-01-25T09:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T08:15:00Z',
#     'tz_time': '2025-01-25T08:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27945.0,
#     'datetime': '2025-01-25T09:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T08:30:00Z',
#     'tz_time': '2025-01-25T08:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 28186.0,
#     'datetime': '2025-01-25T09:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T08:45:00Z',
#     'tz_time': '2025-01-25T08:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 28517.0,
#     'datetime': '2025-01-25T10:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T09:00:00Z',
#     'tz_time': '2025-01-25T09:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 28596.0,
#     'datetime': '2025-01-25T10:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T09:15:00Z',
#     'tz_time': '2025-01-25T09:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 28589.0,
#     'datetime': '2025-01-25T10:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T09:30:00Z',
#     'tz_time': '2025-01-25T09:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 28513.0,
#     'datetime': '2025-01-25T10:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T09:45:00Z',
#     'tz_time': '2025-01-25T09:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 28431.0,
#     'datetime': '2025-01-25T11:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T10:00:00Z',
#     'tz_time': '2025-01-25T10:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 28273.0,
#     'datetime': '2025-01-25T11:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T10:15:00Z',
#     'tz_time': '2025-01-25T10:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 28104.0,
#     'datetime': '2025-01-25T11:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T10:30:00Z',
#     'tz_time': '2025-01-25T10:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27941.0,
#     'datetime': '2025-01-25T11:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T10:45:00Z',
#     'tz_time': '2025-01-25T10:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27718.0,
#     'datetime': '2025-01-25T12:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T11:00:00Z',
#     'tz_time': '2025-01-25T11:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27618.0,
#     'datetime': '2025-01-25T12:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T11:15:00Z',
#     'tz_time': '2025-01-25T11:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27571.0,
#     'datetime': '2025-01-25T12:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T11:30:00Z',
#     'tz_time': '2025-01-25T11:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27565.0,
#     'datetime': '2025-01-25T12:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T11:45:00Z',
#     'tz_time': '2025-01-25T11:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27578.0,
#     'datetime': '2025-01-25T13:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T12:00:00Z',
#     'tz_time': '2025-01-25T12:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27610.0,
#     'datetime': '2025-01-25T13:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T12:15:00Z',
#     'tz_time': '2025-01-25T12:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27637.0,
#     'datetime': '2025-01-25T13:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T12:30:00Z',
#     'tz_time': '2025-01-25T12:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27642.0,
#     'datetime': '2025-01-25T13:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T12:45:00Z',
#     'tz_time': '2025-01-25T12:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27720.0,
#     'datetime': '2025-01-25T14:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T13:00:00Z',
#     'tz_time': '2025-01-25T13:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27628.0,
#     'datetime': '2025-01-25T14:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T13:15:00Z',
#     'tz_time': '2025-01-25T13:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27470.0,
#     'datetime': '2025-01-25T14:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T13:30:00Z',
#     'tz_time': '2025-01-25T13:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27272.0,
#     'datetime': '2025-01-25T14:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T13:45:00Z',
#     'tz_time': '2025-01-25T13:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 26995.0,
#     'datetime': '2025-01-25T15:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T14:00:00Z',
#     'tz_time': '2025-01-25T14:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 26824.0,
#     'datetime': '2025-01-25T15:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T14:15:00Z',
#     'tz_time': '2025-01-25T14:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 26711.0,
#     'datetime': '2025-01-25T15:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T14:30:00Z',
#     'tz_time': '2025-01-25T14:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 26654.0,
#     'datetime': '2025-01-25T15:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T14:45:00Z',
#     'tz_time': '2025-01-25T14:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 26565.0,
#     'datetime': '2025-01-25T16:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T15:00:00Z',
#     'tz_time': '2025-01-25T15:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 26586.0,
#     'datetime': '2025-01-25T16:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T15:15:00Z',
#     'tz_time': '2025-01-25T15:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 26638.0,
#     'datetime': '2025-01-25T16:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T15:30:00Z',
#     'tz_time': '2025-01-25T15:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 26745.0,
#     'datetime': '2025-01-25T16:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T15:45:00Z',
#     'tz_time': '2025-01-25T15:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 26713.0,
#     'datetime': '2025-01-25T17:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T16:00:00Z',
#     'tz_time': '2025-01-25T16:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27027.0,
#     'datetime': '2025-01-25T17:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T16:15:00Z',
#     'tz_time': '2025-01-25T16:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27474.0,
#     'datetime': '2025-01-25T17:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T16:30:00Z',
#     'tz_time': '2025-01-25T16:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 28004.0,
#     'datetime': '2025-01-25T17:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T16:45:00Z',
#     'tz_time': '2025-01-25T16:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 28705.0,
#     'datetime': '2025-01-25T18:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T17:00:00Z',
#     'tz_time': '2025-01-25T17:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 29193.0,
#     'datetime': '2025-01-25T18:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T17:15:00Z',
#     'tz_time': '2025-01-25T17:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 29570.0,
#     'datetime': '2025-01-25T18:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T17:30:00Z',
#     'tz_time': '2025-01-25T17:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 29850.0,
#     'datetime': '2025-01-25T18:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T17:45:00Z',
#     'tz_time': '2025-01-25T17:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30126.0,
#     'datetime': '2025-01-25T19:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T18:00:00Z',
#     'tz_time': '2025-01-25T18:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30303.0,
#     'datetime': '2025-01-25T19:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T18:15:00Z',
#     'tz_time': '2025-01-25T18:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30467.0,
#     'datetime': '2025-01-25T19:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T18:30:00Z',
#     'tz_time': '2025-01-25T18:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30626.0,
#     'datetime': '2025-01-25T19:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T18:45:00Z',
#     'tz_time': '2025-01-25T18:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30809.0,
#     'datetime': '2025-01-25T20:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T19:00:00Z',
#     'tz_time': '2025-01-25T19:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30957.0,
#     'datetime': '2025-01-25T20:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T19:15:00Z',
#     'tz_time': '2025-01-25T19:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31091.0,
#     'datetime': '2025-01-25T20:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T19:30:00Z',
#     'tz_time': '2025-01-25T19:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31166.0,
#     'datetime': '2025-01-25T20:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T19:45:00Z',
#     'tz_time': '2025-01-25T19:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31478.0,
#     'datetime': '2025-01-25T21:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T20:00:00Z',
#     'tz_time': '2025-01-25T20:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31266.0,
#     'datetime': '2025-01-25T21:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T20:15:00Z',
#     'tz_time': '2025-01-25T20:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30847.0,
#     'datetime': '2025-01-25T21:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T20:30:00Z',
#     'tz_time': '2025-01-25T20:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30269.0,
#     'datetime': '2025-01-25T21:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T20:45:00Z',
#     'tz_time': '2025-01-25T20:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 29632.0,
#     'datetime': '2025-01-25T22:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T21:00:00Z',
#     'tz_time': '2025-01-25T21:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 28941.0,
#     'datetime': '2025-01-25T22:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T21:15:00Z',
#     'tz_time': '2025-01-25T21:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 28284.0,
#     'datetime': '2025-01-25T22:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T21:30:00Z',
#     'tz_time': '2025-01-25T21:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27669.0,
#     'datetime': '2025-01-25T22:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T21:45:00Z',
#     'tz_time': '2025-01-25T21:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27052.0,
#     'datetime': '2025-01-25T23:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T22:00:00Z',
#     'tz_time': '2025-01-25T22:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 26507.0,
#     'datetime': '2025-01-25T23:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T22:15:00Z',
#     'tz_time': '2025-01-25T22:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 25990.0,
#     'datetime': '2025-01-25T23:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T22:30:00Z',
#     'tz_time': '2025-01-25T22:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 25496.0,
#     'datetime': '2025-01-25T23:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T22:45:00Z',
#     'tz_time': '2025-01-25T22:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 25011.0,
#     'datetime': '2025-01-26T00:00:00.000+01:00',
#     'datetime_utc': '2025-01-25T23:00:00Z',
#     'tz_time': '2025-01-25T23:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 24551.0,
#     'datetime': '2025-01-26T00:15:00.000+01:00',
#     'datetime_utc': '2025-01-25T23:15:00Z',
#     'tz_time': '2025-01-25T23:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 24102.0,
#     'datetime': '2025-01-26T00:30:00.000+01:00',
#     'datetime_utc': '2025-01-25T23:30:00Z',
#     'tz_time': '2025-01-25T23:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 23665.0,
#     'datetime': '2025-01-26T00:45:00.000+01:00',
#     'datetime_utc': '2025-01-25T23:45:00Z',
#     'tz_time': '2025-01-25T23:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 23227.0,
#     'datetime': '2025-01-26T01:00:00.000+01:00',
#     'datetime_utc': '2025-01-26T00:00:00Z',
#     'tz_time': '2025-01-26T00:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22810.0,
#     'datetime': '2025-01-26T01:15:00.000+01:00',
#     'datetime_utc': '2025-01-26T00:15:00Z',
#     'tz_time': '2025-01-26T00:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22404.0,
#     'datetime': '2025-01-26T01:30:00.000+01:00',
#     'datetime_utc': '2025-01-26T00:30:00Z',
#     'tz_time': '2025-01-26T00:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22023.0,
#     'datetime': '2025-01-26T01:45:00.000+01:00',
#     'datetime_utc': '2025-01-26T00:45:00Z',
#     'tz_time': '2025-01-26T00:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 21583.0,
#     'datetime': '2025-01-26T02:00:00.000+01:00',
#     'datetime_utc': '2025-01-26T01:00:00Z',
#     'tz_time': '2025-01-26T01:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 21292.0,
#     'datetime': '2025-01-26T02:15:00.000+01:00',
#     'datetime_utc': '2025-01-26T01:15:00Z',
#     'tz_time': '2025-01-26T01:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 21060.0,
#     'datetime': '2025-01-26T02:30:00.000+01:00',
#     'datetime_utc': '2025-01-26T01:30:00Z',
#     'tz_time': '2025-01-26T01:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 20879.0,
#     'datetime': '2025-01-26T02:45:00.000+01:00',
#     'datetime_utc': '2025-01-26T01:45:00Z',
#     'tz_time': '2025-01-26T01:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 20699.0,
#     'datetime': '2025-01-26T03:00:00.000+01:00',
#     'datetime_utc': '2025-01-26T02:00:00Z',
#     'tz_time': '2025-01-26T02:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 20576.0,
#     'datetime': '2025-01-26T03:15:00.000+01:00',
#     'datetime_utc': '2025-01-26T02:15:00Z',
#     'tz_time': '2025-01-26T02:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 20464.0,
#     'datetime': '2025-01-26T03:30:00.000+01:00',
#     'datetime_utc': '2025-01-26T02:30:00Z',
#     'tz_time': '2025-01-26T02:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 20365.0,
#     'datetime': '2025-01-26T03:45:00.000+01:00',
#     'datetime_utc': '2025-01-26T02:45:00Z',
#     'tz_time': '2025-01-26T02:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 20234.0,
#     'datetime': '2025-01-26T04:00:00.000+01:00',
#     'datetime_utc': '2025-01-26T03:00:00Z',
#     'tz_time': '2025-01-26T03:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 20179.0,
#     'datetime': '2025-01-26T04:15:00.000+01:00',
#     'datetime_utc': '2025-01-26T03:15:00Z',
#     'tz_time': '2025-01-26T03:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 20154.0,
#     'datetime': '2025-01-26T04:30:00.000+01:00',
#     'datetime_utc': '2025-01-26T03:30:00Z',
#     'tz_time': '2025-01-26T03:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 20160.0,
#     'datetime': '2025-01-26T04:45:00.000+01:00',
#     'datetime_utc': '2025-01-26T03:45:00Z',
#     'tz_time': '2025-01-26T03:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 20132.0,
#     'datetime': '2025-01-26T05:00:00.000+01:00',
#     'datetime_utc': '2025-01-26T04:00:00Z',
#     'tz_time': '2025-01-26T04:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 20203.0,
#     'datetime': '2025-01-26T05:15:00.000+01:00',
#     'datetime_utc': '2025-01-26T04:15:00Z',
#     'tz_time': '2025-01-26T04:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 20309.0,
#     'datetime': '2025-01-26T05:30:00.000+01:00',
#     'datetime_utc': '2025-01-26T04:30:00Z',
#     'tz_time': '2025-01-26T04:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 20449.0,
#     'datetime': '2025-01-26T05:45:00.000+01:00',
#     'datetime_utc': '2025-01-26T04:45:00Z',
#     'tz_time': '2025-01-26T04:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 20562.0,
#     'datetime': '2025-01-26T06:00:00.000+01:00',
#     'datetime_utc': '2025-01-26T05:00:00Z',
#     'tz_time': '2025-01-26T05:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 20772.0,
#     'datetime': '2025-01-26T06:15:00.000+01:00',
#     'datetime_utc': '2025-01-26T05:15:00Z',
#     'tz_time': '2025-01-26T05:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 21013.0,
#     'datetime': '2025-01-26T06:30:00.000+01:00',
#     'datetime_utc': '2025-01-26T05:30:00Z',
#     'tz_time': '2025-01-26T05:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 21275.0,
#     'datetime': '2025-01-26T06:45:00.000+01:00',
#     'datetime_utc': '2025-01-26T05:45:00Z',
#     'tz_time': '2025-01-26T05:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 21571.0,
#     'datetime': '2025-01-26T07:00:00.000+01:00',
#     'datetime_utc': '2025-01-26T06:00:00Z',
#     'tz_time': '2025-01-26T06:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 21824.0,
#     'datetime': '2025-01-26T07:15:00.000+01:00',
#     'datetime_utc': '2025-01-26T06:15:00Z',
#     'tz_time': '2025-01-26T06:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22057.0,
#     'datetime': '2025-01-26T07:30:00.000+01:00',
#     'datetime_utc': '2025-01-26T06:30:00Z',
#     'tz_time': '2025-01-26T06:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22285.0,
#     'datetime': '2025-01-26T07:45:00.000+01:00',
#     'datetime_utc': '2025-01-26T06:45:00Z',
#     'tz_time': '2025-01-26T06:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22451.0,
#     'datetime': '2025-01-26T08:00:00.000+01:00',
#     'datetime_utc': '2025-01-26T07:00:00Z',
#     'tz_time': '2025-01-26T07:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 22740.0,
#     'datetime': '2025-01-26T08:15:00.000+01:00',
#     'datetime_utc': '2025-01-26T07:15:00Z',
#     'tz_time': '2025-01-26T07:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 23086.0,
#     'datetime': '2025-01-26T08:30:00.000+01:00',
#     'datetime_utc': '2025-01-26T07:30:00Z',
#     'tz_time': '2025-01-26T07:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 23470.0,
#     'datetime': '2025-01-26T08:45:00.000+01:00',
#     'datetime_utc': '2025-01-26T07:45:00Z',
#     'tz_time': '2025-01-26T07:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 23929.0,
#     'datetime': '2025-01-26T09:00:00.000+01:00',
#     'datetime_utc': '2025-01-26T08:00:00Z',
# ...
#     'datetime': '2025-01-30T04:45:00.000+01:00',
#     'datetime_utc': '2025-01-30T03:45:00Z',
#     'tz_time': '2025-01-30T03:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 23439.0,
#     'datetime': '2025-01-30T05:00:00.000+01:00',
#     'datetime_utc': '2025-01-30T04:00:00Z',
#     'tz_time': '2025-01-30T04:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 23790.0,
#     'datetime': '2025-01-30T05:15:00.000+01:00',
#     'datetime_utc': '2025-01-30T04:15:00Z',
#     'tz_time': '2025-01-30T04:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 24295.0,
#     'datetime': '2025-01-30T05:30:00.000+01:00',
#     'datetime_utc': '2025-01-30T04:30:00Z',
#     'tz_time': '2025-01-30T04:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 24952.0,
#     'datetime': '2025-01-30T05:45:00.000+01:00',
#     'datetime_utc': '2025-01-30T04:45:00Z',
#     'tz_time': '2025-01-30T04:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 25560.0,
#     'datetime': '2025-01-30T06:00:00.000+01:00',
#     'datetime_utc': '2025-01-30T05:00:00Z',
#     'tz_time': '2025-01-30T05:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 26489.0,
#     'datetime': '2025-01-30T06:15:00.000+01:00',
#     'datetime_utc': '2025-01-30T05:15:00Z',
#     'tz_time': '2025-01-30T05:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 27535.0,
#     'datetime': '2025-01-30T06:30:00.000+01:00',
#     'datetime_utc': '2025-01-30T05:30:00Z',
#     'tz_time': '2025-01-30T05:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 28642.0,
#     'datetime': '2025-01-30T06:45:00.000+01:00',
#     'datetime_utc': '2025-01-30T05:45:00Z',
#     'tz_time': '2025-01-30T05:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30005.0,
#     'datetime': '2025-01-30T07:00:00.000+01:00',
#     'datetime_utc': '2025-01-30T06:00:00Z',
#     'tz_time': '2025-01-30T06:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31050.0,
#     'datetime': '2025-01-30T07:15:00.000+01:00',
#     'datetime_utc': '2025-01-30T06:15:00Z',
#     'tz_time': '2025-01-30T06:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31969.0,
#     'datetime': '2025-01-30T07:30:00.000+01:00',
#     'datetime_utc': '2025-01-30T06:30:00Z',
#     'tz_time': '2025-01-30T06:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32742.0,
#     'datetime': '2025-01-30T07:45:00.000+01:00',
#     'datetime_utc': '2025-01-30T06:45:00Z',
#     'tz_time': '2025-01-30T06:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33718.0,
#     'datetime': '2025-01-30T08:00:00.000+01:00',
#     'datetime_utc': '2025-01-30T07:00:00Z',
#     'tz_time': '2025-01-30T07:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 34171.0,
#     'datetime': '2025-01-30T08:15:00.000+01:00',
#     'datetime_utc': '2025-01-30T07:15:00Z',
#     'tz_time': '2025-01-30T07:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 34451.0,
#     'datetime': '2025-01-30T08:30:00.000+01:00',
#     'datetime_utc': '2025-01-30T07:30:00Z',
#     'tz_time': '2025-01-30T07:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 34590.0,
#     'datetime': '2025-01-30T08:45:00.000+01:00',
#     'datetime_utc': '2025-01-30T07:45:00Z',
#     'tz_time': '2025-01-30T07:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 34728.0,
#     'datetime': '2025-01-30T09:00:00.000+01:00',
#     'datetime_utc': '2025-01-30T08:00:00Z',
#     'tz_time': '2025-01-30T08:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 34708.0,
#     'datetime': '2025-01-30T09:15:00.000+01:00',
#     'datetime_utc': '2025-01-30T08:15:00Z',
#     'tz_time': '2025-01-30T08:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 34660.0,
#     'datetime': '2025-01-30T09:30:00.000+01:00',
#     'datetime_utc': '2025-01-30T08:30:00Z',
#     'tz_time': '2025-01-30T08:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 34586.0,
#     'datetime': '2025-01-30T09:45:00.000+01:00',
#     'datetime_utc': '2025-01-30T08:45:00Z',
#     'tz_time': '2025-01-30T08:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 34556.0,
#     'datetime': '2025-01-30T10:00:00.000+01:00',
#     'datetime_utc': '2025-01-30T09:00:00Z',
#     'tz_time': '2025-01-30T09:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 34406.0,
#     'datetime': '2025-01-30T10:15:00.000+01:00',
#     'datetime_utc': '2025-01-30T09:15:00Z',
#     'tz_time': '2025-01-30T09:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 34213.0,
#     'datetime': '2025-01-30T10:30:00.000+01:00',
#     'datetime_utc': '2025-01-30T09:30:00Z',
#     'tz_time': '2025-01-30T09:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33995.0,
#     'datetime': '2025-01-30T10:45:00.000+01:00',
#     'datetime_utc': '2025-01-30T09:45:00Z',
#     'tz_time': '2025-01-30T09:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33724.0,
#     'datetime': '2025-01-30T11:00:00.000+01:00',
#     'datetime_utc': '2025-01-30T10:00:00Z',
#     'tz_time': '2025-01-30T10:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33524.0,
#     'datetime': '2025-01-30T11:15:00.000+01:00',
#     'datetime_utc': '2025-01-30T10:15:00Z',
#     'tz_time': '2025-01-30T10:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33364.0,
#     'datetime': '2025-01-30T11:30:00.000+01:00',
#     'datetime_utc': '2025-01-30T10:30:00Z',
#     'tz_time': '2025-01-30T10:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33240.0,
#     'datetime': '2025-01-30T11:45:00.000+01:00',
#     'datetime_utc': '2025-01-30T10:45:00Z',
#     'tz_time': '2025-01-30T10:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33107.0,
#     'datetime': '2025-01-30T12:00:00.000+01:00',
#     'datetime_utc': '2025-01-30T11:00:00Z',
#     'tz_time': '2025-01-30T11:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33038.0,
#     'datetime': '2025-01-30T12:15:00.000+01:00',
#     'datetime_utc': '2025-01-30T11:15:00Z',
#     'tz_time': '2025-01-30T11:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32986.0,
#     'datetime': '2025-01-30T12:30:00.000+01:00',
#     'datetime_utc': '2025-01-30T11:30:00Z',
#     'tz_time': '2025-01-30T11:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32942.0,
#     'datetime': '2025-01-30T12:45:00.000+01:00',
#     'datetime_utc': '2025-01-30T11:45:00Z',
#     'tz_time': '2025-01-30T11:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32921.0,
#     'datetime': '2025-01-30T13:00:00.000+01:00',
#     'datetime_utc': '2025-01-30T12:00:00Z',
#     'tz_time': '2025-01-30T12:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32867.0,
#     'datetime': '2025-01-30T13:15:00.000+01:00',
#     'datetime_utc': '2025-01-30T12:15:00Z',
#     'tz_time': '2025-01-30T12:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32796.0,
#     'datetime': '2025-01-30T13:30:00.000+01:00',
#     'datetime_utc': '2025-01-30T12:30:00Z',
#     'tz_time': '2025-01-30T12:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32710.0,
#     'datetime': '2025-01-30T13:45:00.000+01:00',
#     'datetime_utc': '2025-01-30T12:45:00Z',
#     'tz_time': '2025-01-30T12:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32619.0,
#     'datetime': '2025-01-30T14:00:00.000+01:00',
#     'datetime_utc': '2025-01-30T13:00:00Z',
#     'tz_time': '2025-01-30T13:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32519.0,
#     'datetime': '2025-01-30T14:15:00.000+01:00',
#     'datetime_utc': '2025-01-30T13:15:00Z',
#     'tz_time': '2025-01-30T13:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32422.0,
#     'datetime': '2025-01-30T14:30:00.000+01:00',
#     'datetime_utc': '2025-01-30T13:30:00Z',
#     'tz_time': '2025-01-30T13:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32337.0,
#     'datetime': '2025-01-30T14:45:00.000+01:00',
#     'datetime_utc': '2025-01-30T13:45:00Z',
#     'tz_time': '2025-01-30T13:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32197.0,
#     'datetime': '2025-01-30T15:00:00.000+01:00',
#     'datetime_utc': '2025-01-30T14:00:00Z',
#     'tz_time': '2025-01-30T14:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32178.0,
#     'datetime': '2025-01-30T15:15:00.000+01:00',
#     'datetime_utc': '2025-01-30T14:15:00Z',
#     'tz_time': '2025-01-30T14:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32208.0,
#     'datetime': '2025-01-30T15:30:00.000+01:00',
#     'datetime_utc': '2025-01-30T14:30:00Z',
#     'tz_time': '2025-01-30T14:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32278.0,
#     'datetime': '2025-01-30T15:45:00.000+01:00',
#     'datetime_utc': '2025-01-30T14:45:00Z',
#     'tz_time': '2025-01-30T14:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32339.0,
#     'datetime': '2025-01-30T16:00:00.000+01:00',
#     'datetime_utc': '2025-01-30T15:00:00Z',
#     'tz_time': '2025-01-30T15:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32458.0,
#     'datetime': '2025-01-30T16:15:00.000+01:00',
#     'datetime_utc': '2025-01-30T15:15:00Z',
#     'tz_time': '2025-01-30T15:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32590.0,
#     'datetime': '2025-01-30T16:30:00.000+01:00',
#     'datetime_utc': '2025-01-30T15:30:00Z',
#     'tz_time': '2025-01-30T15:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32754.0,
#     'datetime': '2025-01-30T16:45:00.000+01:00',
#     'datetime_utc': '2025-01-30T15:45:00Z',
#     'tz_time': '2025-01-30T15:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32818.0,
#     'datetime': '2025-01-30T17:00:00.000+01:00',
#     'datetime_utc': '2025-01-30T16:00:00Z',
#     'tz_time': '2025-01-30T16:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33122.0,
#     'datetime': '2025-01-30T17:15:00.000+01:00',
#     'datetime_utc': '2025-01-30T16:15:00Z',
#     'tz_time': '2025-01-30T16:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33524.0,
#     'datetime': '2025-01-30T17:30:00.000+01:00',
#     'datetime_utc': '2025-01-30T16:30:00Z',
#     'tz_time': '2025-01-30T16:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33987.0,
#     'datetime': '2025-01-30T17:45:00.000+01:00',
#     'datetime_utc': '2025-01-30T16:45:00Z',
#     'tz_time': '2025-01-30T16:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 34557.0,
#     'datetime': '2025-01-30T18:00:00.000+01:00',
#     'datetime_utc': '2025-01-30T17:00:00Z',
#     'tz_time': '2025-01-30T17:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 35007.0,
#     'datetime': '2025-01-30T18:15:00.000+01:00',
#     'datetime_utc': '2025-01-30T17:15:00Z',
#     'tz_time': '2025-01-30T17:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 35392.0,
#     'datetime': '2025-01-30T18:30:00.000+01:00',
#     'datetime_utc': '2025-01-30T17:30:00Z',
#     'tz_time': '2025-01-30T17:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 35721.0,
#     'datetime': '2025-01-30T18:45:00.000+01:00',
#     'datetime_utc': '2025-01-30T17:45:00Z',
#     'tz_time': '2025-01-30T17:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 36050.0,
#     'datetime': '2025-01-30T19:00:00.000+01:00',
#     'datetime_utc': '2025-01-30T18:00:00Z',
#     'tz_time': '2025-01-30T18:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 36334.0,
#     'datetime': '2025-01-30T19:15:00.000+01:00',
#     'datetime_utc': '2025-01-30T18:15:00Z',
#     'tz_time': '2025-01-30T18:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 36618.0,
#     'datetime': '2025-01-30T19:30:00.000+01:00',
#     'datetime_utc': '2025-01-30T18:30:00Z',
#     'tz_time': '2025-01-30T18:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 36876.0,
#     'datetime': '2025-01-30T19:45:00.000+01:00',
#     'datetime_utc': '2025-01-30T18:45:00Z',
#     'tz_time': '2025-01-30T18:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 37296.0,
#     'datetime': '2025-01-30T20:00:00.000+01:00',
#     'datetime_utc': '2025-01-30T19:00:00Z',
#     'tz_time': '2025-01-30T19:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 37397.0,
#     'datetime': '2025-01-30T20:15:00.000+01:00',
#     'datetime_utc': '2025-01-30T19:15:00Z',
#     'tz_time': '2025-01-30T19:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 37367.0,
#     'datetime': '2025-01-30T20:30:00.000+01:00',
#     'datetime_utc': '2025-01-30T19:30:00Z',
#     'tz_time': '2025-01-30T19:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 37184.0,
#     'datetime': '2025-01-30T20:45:00.000+01:00',
#     'datetime_utc': '2025-01-30T19:45:00Z',
#     'tz_time': '2025-01-30T19:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 37220.0,
#     'datetime': '2025-01-30T21:00:00.000+01:00',
#     'datetime_utc': '2025-01-30T20:00:00Z',
#     'tz_time': '2025-01-30T20:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 36658.0,
#     'datetime': '2025-01-30T21:15:00.000+01:00',
#     'datetime_utc': '2025-01-30T20:15:00Z',
#     'tz_time': '2025-01-30T20:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 35890.0,
#     'datetime': '2025-01-30T21:30:00.000+01:00',
#     'datetime_utc': '2025-01-30T20:30:00Z',
#     'tz_time': '2025-01-30T20:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 34972.0,
#     'datetime': '2025-01-30T21:45:00.000+01:00',
#     'datetime_utc': '2025-01-30T20:45:00Z',
#     'tz_time': '2025-01-30T20:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 33992.0,
#     'datetime': '2025-01-30T22:00:00.000+01:00',
#     'datetime_utc': '2025-01-30T21:00:00Z',
#     'tz_time': '2025-01-30T21:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32991.0,
#     'datetime': '2025-01-30T22:15:00.000+01:00',
#     'datetime_utc': '2025-01-30T21:15:00Z',
#     'tz_time': '2025-01-30T21:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 32047.0,
#     'datetime': '2025-01-30T22:30:00.000+01:00',
#     'datetime_utc': '2025-01-30T21:30:00Z',
#     'tz_time': '2025-01-30T21:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 31177.0,
#     'datetime': '2025-01-30T22:45:00.000+01:00',
#     'datetime_utc': '2025-01-30T21:45:00Z',
#     'tz_time': '2025-01-30T21:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 30251.0,
#     'datetime': '2025-01-30T23:00:00.000+01:00',
#     'datetime_utc': '2025-01-30T22:00:00Z',
#     'tz_time': '2025-01-30T22:00:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 29558.0,
#     'datetime': '2025-01-30T23:15:00.000+01:00',
#     'datetime_utc': '2025-01-30T22:15:00Z',
#     'tz_time': '2025-01-30T22:15:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 28958.0,
#     'datetime': '2025-01-30T23:30:00.000+01:00',
#     'datetime_utc': '2025-01-30T22:30:00Z',
#     'tz_time': '2025-01-30T22:30:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'},
#    {'value': 28429.0,
#     'datetime': '2025-01-30T23:45:00.000+01:00',
#     'datetime_utc': '2025-01-30T22:45:00Z',
#     'tz_time': '2025-01-30T22:45:00.000Z',
#     'geo_id': 8741,
#     'geo_name': 'Península'}]}}

# %% [markdown]
# It looks like the data is stored under the key `'values'` in the JSON response. Let's extract the data and save it to a file.

# %%
raw_data = response_json['indicator']['values']

data = pd.DataFrame(raw_data)

data.tail()
# Out:
#        value                       datetime          datetime_utc  \
# 667  31177.0  2025-01-30T22:45:00.000+01:00  2025-01-30T21:45:00Z
# 668  30251.0  2025-01-30T23:00:00.000+01:00  2025-01-30T22:00:00Z
# 669  29558.0  2025-01-30T23:15:00.000+01:00  2025-01-30T22:15:00Z
# 670  28958.0  2025-01-30T23:30:00.000+01:00  2025-01-30T22:30:00Z
# 671  28429.0  2025-01-30T23:45:00.000+01:00  2025-01-30T22:45:00Z
#
#                       tz_time  geo_id   geo_name
# 667  2025-01-30T21:45:00.000Z    8741  Península
# 668  2025-01-30T22:00:00.000Z    8741  Península
# 669  2025-01-30T22:15:00.000Z    8741  Península
# 670  2025-01-30T22:30:00.000Z    8741  Península
# 671  2025-01-30T22:45:00.000Z    8741  Península

# %% [markdown]
# Let's analyze the data and plot it.

# %%
# unique geo_name values

data['geo_name'].unique()
# Out:
# array(['Península'], dtype=object)

# %% [markdown]
# It looks like the data has a granularity of 15 minutes. Let's convert `datetime` column to a `datetime` object and plot the data.

# %%
data['datetime'] = pd.to_datetime(data['datetime'])

# %%
from plotly import express as px

fig = px.line(data, x='datetime', y='value', color='geo_name', title='Electricity demand forecast (15 min)')

fig.show()

# %% [markdown]
# Let's compare the forecasted demand for the previous date and the current date, and see if there is any difference. We have to be smart about the date selection, since usually API requests are not free, and we don't want to make too many requests.
#
# We need to adjust the date selection to get the data for the previous day and the Christmas' Eve day.

# %%
indicator_id = 460

# when we want to get the data for a specific date range, we need to provide the start and end date
# in the ISO 8601 format: YYYY-MM-DDTHH:MM:SSZ
# since the hour in Spain is UTC+1 in winter and UTC+2 in summer, we need to adjust the hour
start_date = '2024-12-22T23:00:00Z' 
end_date = '2024-12-24T22:59:59Z'

# the API endpoint
url = f'https://api.esios.ree.es/indicators/{indicator_id}'

# define the headers
headers = {
    'Accept': 'application/json; application/vnd.esios-api-v1+json',
    'Content-Type': 'application/json',
    'x-api-key': f'{api_token}'
}

# define the parameters, in our case the start and end date
params = {
    'start_date': start_date,
    'end_date': end_date
}

# Make the GET request
response = requests.get(url, headers=headers, params=params)
response_json = response.json()

# convert to a DataFrame
raw_data = response_json['indicator']['values']

data = pd.DataFrame(raw_data)

data['datetime'] = pd.to_datetime(data['datetime'])
data['date'] = data['datetime'].dt.date

data.head()
# Out:
#      value                  datetime          datetime_utc  \
# 0  24441.0 2024-12-23 00:00:00+01:00  2024-12-22T23:00:00Z
# 1  23917.0 2024-12-23 00:15:00+01:00  2024-12-22T23:15:00Z
# 2  23399.0 2024-12-23 00:30:00+01:00  2024-12-22T23:30:00Z
# 3  22897.0 2024-12-23 00:45:00+01:00  2024-12-22T23:45:00Z
# 4  22401.0 2024-12-23 01:00:00+01:00  2024-12-23T00:00:00Z
#
#                     tz_time  geo_id   geo_name        date
# 0  2024-12-22T23:00:00.000Z    8741  Península  2024-12-23
# 1  2024-12-22T23:15:00.000Z    8741  Península  2024-12-23
# 2  2024-12-22T23:30:00.000Z    8741  Península  2024-12-23
# 3  2024-12-22T23:45:00.000Z    8741  Península  2024-12-23
# 4  2024-12-23T00:00:00.000Z    8741  Península  2024-12-23

# %% [markdown]
# Since we want to compare the 15-minute data, let's extract the hour and minute from the `datetime` column and plot the data for the two dates.

# %%
data['time'] = data['datetime'].dt.time

data.head()
# Out:
#      value                  datetime          datetime_utc  \
# 0  24441.0 2024-12-23 00:00:00+01:00  2024-12-22T23:00:00Z
# 1  23917.0 2024-12-23 00:15:00+01:00  2024-12-22T23:15:00Z
# 2  23399.0 2024-12-23 00:30:00+01:00  2024-12-22T23:30:00Z
# 3  22897.0 2024-12-23 00:45:00+01:00  2024-12-22T23:45:00Z
# 4  22401.0 2024-12-23 01:00:00+01:00  2024-12-23T00:00:00Z
#
#                     tz_time  geo_id   geo_name        date      time
# 0  2024-12-22T23:00:00.000Z    8741  Península  2024-12-23  00:00:00
# 1  2024-12-22T23:15:00.000Z    8741  Península  2024-12-23  00:15:00
# 2  2024-12-22T23:30:00.000Z    8741  Península  2024-12-23  00:30:00
# 3  2024-12-22T23:45:00.000Z    8741  Península  2024-12-23  00:45:00
# 4  2024-12-23T00:00:00.000Z    8741  Península  2024-12-23  01:00:00

# %% [markdown]
# Let's create two variables, each one containing the data for the two dates we are interested in.

# %%
from datetime import datetime

december_23 = data[data['date'] == datetime(2024, 12, 23).date()]
december_24 = data[data['date'] == datetime(2024, 12, 24).date()]

december_23
# Out:
#       value                  datetime          datetime_utc  \
# 0   24441.0 2024-12-23 00:00:00+01:00  2024-12-22T23:00:00Z
# 1   23917.0 2024-12-23 00:15:00+01:00  2024-12-22T23:15:00Z
# 2   23399.0 2024-12-23 00:30:00+01:00  2024-12-22T23:30:00Z
# 3   22897.0 2024-12-23 00:45:00+01:00  2024-12-22T23:45:00Z
# 4   22401.0 2024-12-23 01:00:00+01:00  2024-12-23T00:00:00Z
# ..      ...                       ...                   ...
# 91  28360.0 2024-12-23 22:45:00+01:00  2024-12-23T21:45:00Z
# 92  27687.0 2024-12-23 23:00:00+01:00  2024-12-23T22:00:00Z
# 93  26933.0 2024-12-23 23:15:00+01:00  2024-12-23T22:15:00Z
# 94  26237.0 2024-12-23 23:30:00+01:00  2024-12-23T22:30:00Z
# 95  25595.0 2024-12-23 23:45:00+01:00  2024-12-23T22:45:00Z
#
#                      tz_time  geo_id   geo_name        date      time
# 0   2024-12-22T23:00:00.000Z    8741  Península  2024-12-23  00:00:00
# 1   2024-12-22T23:15:00.000Z    8741  Península  2024-12-23  00:15:00
# 2   2024-12-22T23:30:00.000Z    8741  Península  2024-12-23  00:30:00
# 3   2024-12-22T23:45:00.000Z    8741  Península  2024-12-23  00:45:00
# 4   2024-12-23T00:00:00.000Z    8741  Península  2024-12-23  01:00:00
# ..                       ...     ...        ...         ...       ...
# 91  2024-12-23T21:45:00.000Z    8741  Península  2024-12-23  22:45:00
# 92  2024-12-23T22:00:00.000Z    8741  Península  2024-12-23  23:00:00
# 93  2024-12-23T22:15:00.000Z    8741  Península  2024-12-23  23:15:00
# 94  2024-12-23T22:30:00.000Z    8741  Península  2024-12-23  23:30:00
# 95  2024-12-23T22:45:00.000Z    8741  Península  2024-12-23  23:45:00
#
# [96 rows x 8 columns]

# %% [markdown]
# Let's plot the two series now, knowing that December 23rd was a Monday and December 24th was a Tuesday, so therefore the demand shouldn't be too different according to the day of the week.

# %%
# use plotly graph objects to plot the two series

from plotly import graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scatter(x=december_23['time'], y=december_23['value'], mode='lines', name='December 23'))
fig.add_trace(go.Scatter(x=december_24['time'], y=december_24['value'], mode='lines', name='December 24'))

fig.update_layout(title='Electricity demand forecast (15 min)', xaxis_title='Time', yaxis_title='Demand (MW)')

fig.show()

# %% [markdown]
# There is quite a difference in the demand forecast for the two days. Let's see the previous monday and tuesday to see if the difference is due to the day of the week.

# %%
indicator_id = 460

# when we want to get the data for a specific date range, we need to provide the start and end date
# in the ISO 8601 format: YYYY-MM-DDTHH:MM:SSZ
# since the hour in Spain is UTC+1 in winter and UTC+2 in summer, we need to adjust the hour
start_date = '2024-12-15T23:00:00Z' 
end_date = '2024-12-17T22:59:59Z'

# the API endpoint
url = f'https://api.esios.ree.es/indicators/{indicator_id}'

# define the headers
headers = {
    'Accept': 'application/json; application/vnd.esios-api-v1+json',
    'Content-Type': 'application/json',
    'x-api-key': f'{api_token}'
}

# define the parameters, in our case the start and end date
params = {
    'start_date': start_date,
    'end_date': end_date
}

# make the GET request
response = requests.get(url, headers=headers, params=params)
response_json = response.json()

# convert to a DataFrame
raw_data = response_json['indicator']['values']

data = pd.DataFrame(raw_data)

data['datetime'] = pd.to_datetime(data['datetime'])
data['date'] = data['datetime'].dt.date
data['time'] = data['datetime'].dt.time

december_16 = data[data['date'] == datetime(2024, 12, 16).date()]
december_17 = data[data['date'] == datetime(2024, 12, 17).date()]

fig = go.Figure()

fig.add_trace(go.Scatter(x=december_16['time'], y=december_16['value'], mode='lines', name='December 16'))
fig.add_trace(go.Scatter(x=december_17['time'], y=december_17['value'], mode='lines', name='December 17'))

fig.update_layout(title='Electricity demand forecast (15 min)', xaxis_title='Time', yaxis_title='Demand (MW)')

fig.show()

# %% [markdown]
# ## Example 4: Create a function to get the data for an indicator between two dates
#
# Instead of repeating the same code to get the data for an indicator between two dates, we can create a function that takes the indicator id, start date, and end date as input parameters, and returns the data for that indicator between the two dates as a DataFrame.

# %%
def get_indicator(indicator_id, start_date, end_date):

    api_token = os.getenv('API_KEY')

    url = f'https://api.esios.ree.es/indicators/{indicator_id}'

    headers = {
        'Accept': 'application/json; application/vnd.esios-api-v1+json',
        'Content-Type': 'application/json',
        'x-api-key': f'{api_token}'
    }

    params = {
        'start_date': start_date,
        'end_date': end_date
    }

    response_json = requests.get(url, headers=headers, params=params).json()

    raw_data = response_json['indicator']['values']

    return pd.DataFrame(raw_data)

get_indicator(544, '2024-12-15T23:00:00Z', '2024-12-17T22:59:59Z')
# Out:
#        value                       datetime          datetime_utc  \
# 0    26392.0  2024-12-16T00:00:00.000+01:00  2024-12-15T23:00:00Z
# 1    26091.0  2024-12-16T00:05:00.000+01:00  2024-12-15T23:05:00Z
# 2    25846.0  2024-12-16T00:10:00.000+01:00  2024-12-15T23:10:00Z
# 3    25656.0  2024-12-16T00:15:00.000+01:00  2024-12-15T23:15:00Z
# 4    25489.0  2024-12-16T00:20:00.000+01:00  2024-12-15T23:20:00Z
# ..       ...                            ...                   ...
# 571  29209.0  2024-12-17T23:35:00.000+01:00  2024-12-17T22:35:00Z
# 572  28963.0  2024-12-17T23:40:00.000+01:00  2024-12-17T22:40:00Z
# 573  28723.0  2024-12-17T23:45:00.000+01:00  2024-12-17T22:45:00Z
# 574  28489.0  2024-12-17T23:50:00.000+01:00  2024-12-17T22:50:00Z
# 575  28262.0  2024-12-17T23:55:00.000+01:00  2024-12-17T22:55:00Z
#
#                       tz_time  geo_id   geo_name
# 0    2024-12-15T23:00:00.000Z    8741  Península
# 1    2024-12-15T23:05:00.000Z    8741  Península
# 2    2024-12-15T23:10:00.000Z    8741  Península
# 3    2024-12-15T23:15:00.000Z    8741  Península
# 4    2024-12-15T23:20:00.000Z    8741  Península
# ..                        ...     ...        ...
# 571  2024-12-17T22:35:00.000Z    8741  Península
# 572  2024-12-17T22:40:00.000Z    8741  Península
# 573  2024-12-17T22:45:00.000Z    8741  Península
# 574  2024-12-17T22:50:00.000Z    8741  Península
# 575  2024-12-17T22:55:00.000Z    8741  Península
#
# [576 rows x 6 columns]

# %% [markdown]
# We can see now that the difference between the indicators 460 and 544 is the granularity of the data. Indicator 460 has a granularity of 15 minutes, while indicator 544 has a granularity of 5 minutes.

# %%
# CHECK OUT FASTAPI LIBRARY
