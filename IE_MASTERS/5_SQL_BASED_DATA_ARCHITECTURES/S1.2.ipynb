# %% [markdown]
# Data Modeling Concepts
#
# 1) Entity Relationship Diagram (ERD)
#
# An introduction to Data Modelling will be covered. Terminologies like entities, attributes, domains, and occurrence, will be explained.
#
# 2) Entities Relationships
#
# Review of Primary & Foreign keys.
#
# 3) Entities Relationships Types
#
# One to One, One to Many, and Many to Many relationships. There will be examples of all these different types. Students will be explained how to solve many to many relationships in a relational data model.

# %% [markdown]
# ### Data Modeling Concepts

# %% [markdown]
# #### Entity Relationship Diagram (ERD)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ##### Attribute Types

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Primary & Foreign Keys Review
