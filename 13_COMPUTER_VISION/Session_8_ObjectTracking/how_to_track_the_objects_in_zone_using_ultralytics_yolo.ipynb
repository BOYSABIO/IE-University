# %% [markdown]
# <div align="center">
#
#   <a href="https://ultralytics.com/yolo" target="_blank">
#     <img width="1024", src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png"></a>
#
#   [中文](https://docs.ultralytics.com/zh/) | [한국어](https://docs.ultralytics.com/ko/) | [日本語](https://docs.ultralytics.com/ja/) | [Русский](https://docs.ultralytics.com/ru/) | [Deutsch](https://docs.ultralytics.com/de/) | [Français](https://docs.ultralytics.com/fr/) | [Español](https://docs.ultralytics.com/es/) | [Português](https://docs.ultralytics.com/pt/) | [Türkçe](https://docs.ultralytics.com/tr/) | [Tiếng Việt](https://docs.ultralytics.com/vi/) | [العربية](https://docs.ultralytics.com/ar/)
#
#   <a href="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml"><img src="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml/badge.svg" alt="Ultralytics CI"></a>
#   <a href="https://colab.research.google.com/github/ultralytics/notebooks/blob/main/notebooks/how-to-track-the-objects-in-zone-using-ultralytics-yolo.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#
#   <a href="https://ultralytics.com/discord"><img alt="Discord" src="https://img.shields.io/discord/1089800235347353640?logo=discord&logoColor=white&label=Discord&color=blue"></a>
#   <a href="https://community.ultralytics.com"><img alt="Ultralytics Forums" src="https://img.shields.io/discourse/users?server=https%3A%2F%2Fcommunity.ultralytics.com&logo=discourse&label=Forums&color=blue"></a>
#   <a href="https://reddit.com/r/ultralytics"><img alt="Ultralytics Reddit" src="https://img.shields.io/reddit/subreddit-subscribers/ultralytics?style=flat&logo=reddit&logoColor=white&label=Reddit&color=blue"></a>
#
#   Welcome to the Object tracking in zones using Ultralytics YOLO11 🚀 notebook! <a href="https://github.com/ultralytics/ultralytics">YOLO11</a> is the latest version of the YOLO (You Only Look Once) AI models developed by <a href="https://ultralytics.com">Ultralytics</a>. We hope that the resources in this notebook will help you get the most out of YOLO11. Please browse the YOLO11 <a href="https://docs.ultralytics.com/">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/ultralytics">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!</div>

# %% [markdown]
# # TrackZone using Ultralytics YOLO11
#
# This notebook serves as a starting point for [tracking objects in zones](https://docs.ultralytics.com/guides/trackzone/) in videos or live streams using the YOLO11 model.
#
# ### What is TrackZone?
#
# TrackZone specializes in monitoring objects within designated areas of a frame instead of the whole frame. Built on [Ultralytics YOLO11](https://github.com/ultralytics/ultralytics/), it integrates object detection and tracking specifically within zones for videos and live camera feeds. YOLO11's advanced algorithms and [deep learning](https://www.ultralytics.com/glossary/deep-learning-dl) technologies make it a perfect choice for real-time use cases, offering precise and efficient object tracking in applications like crowd monitoring and surveillance.
#
# ### Advantages of Object Tracking in Zones (TrackZone)
#
# - **Targeted Analysis:** Tracking objects within specific zones allows for more focused insights, enabling precise monitoring and analysis of areas of interest, such as entry points or restricted zones.
# - **Improved Efficiency:** By narrowing the tracking scope to defined zones, TrackZone reduces computational overhead, ensuring faster processing and optimal performance.
# - **Enhanced Security:** Zonal tracking improves surveillance by monitoring critical areas, aiding in the early detection of unusual activity or security breaches.
# - **Scalable Solutions:** The ability to focus on specific zones makes TrackZone adaptable to various scenarios, from retail spaces to industrial settings, ensuring seamless integration and scalability.

# %% [markdown]
# ### Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://www.pepy.tech/projects/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
# %pip install ultralytics

import ultralytics
import cv2
from ultralytics import solutions

ultralytics.checks()
# Out:
# Ultralytics 8.3.146 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.3/112.6 GB disk)

# %% [markdown]
# ### Read the Video File
#
# - You can either read the video file directly or stream the content from an RTSP (Real-Time Streaming Protocol) source, allowing for flexible video input depending on your needs.
# - We will also set up the video writer to handle the output video writing.

# %%
import requests
import cv2
import os

# Download video (if not already downloaded)
import requests
import os

from google.colab import drive
drive.mount('/content/gdrive')
video_filename = "/content/gdrive/MyDrive/IE/Notebooks_ObjectTracking/traffic.mp4"


# Capture video
cap = cv2.VideoCapture(video_filename)
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH,
                                       cv2.CAP_PROP_FRAME_HEIGHT,
                                       cv2.CAP_PROP_FPS))



#cap = cv2.VideoCapture("path/to/video/file.mp4")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH,
                                       cv2.CAP_PROP_FRAME_HEIGHT,
                                       cv2.CAP_PROP_FPS))

# Video writer
video_writer = cv2.VideoWriter("trackzone.avi",
                               cv2.VideoWriter_fourcc(*"mp4v"),
                               fps, (w, h))
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Define Region Coordinates
#
# Here, we set the coordinates for specific regions to ensure accurate object tracking and analysis within the video or stream. This helps monitor and track objects effectively in different areas.

# %%
w,h
# Out:
# (1280, 720)

# %%
# Define region points
# region_points = [(20, 400), (1080, 400)]  # For line tracking
region_points = [(0, 0), (1280, 0), (1280, 720), (0, 720)]  # For rectangle region tracking
# region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360), (20, 400)]  # For polygon region tracking

# %% [markdown]
# ### Initialize the TrackZone Class
#
# - Next, let's initialize the `TrackZone` class to track objects in each frame of the video.

# %%
 # Init TrackZone (Object Tracking in Zones, not complete frame)
trackzone = solutions.TrackZone(
    show=True,  # Display the output
    region=region_points,  # Pass region points
    model="yolo11n.pt",  # You can use any model that Ultralytics support, i.e. YOLOv9, YOLOv10
    # line_width=2,  # Adjust the line width for bounding boxes and text display
    # classes=[0, 2],  # If you want to track specific classes i.e. person and car with COCO pretrained model.
)
# Out:
# Ultralytics Solutions: ✅ {'source': None, 'model': 'yolo11n.pt', 'classes': None, 'show_conf': True, 'show_labels': True, 'region': [(0, 0), (1280, 0), (1280, 720), (0, 720)], 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 2, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': True, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'half': False, 'tracker': 'botsort.yaml', 'verbose': True, 'data': 'images'}
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 78.6MB/s]
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()

# %% [markdown]
# ### Process Video Frames
#
# In this step, we will process each frame of the video to detect and analyze objects. This allows for real-time tracking, based on the visual data in the frames.

# %%
# Process video
while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    trackzone(im0)  # track the objects
    video_writer.write(im0)   # write the video frames

cap.release()   # Release the capture
video_writer.release()
cv2.destroyAllWindows()
# Out:
# Streaming output truncated to the last 5000 lines.
#
# 45: 720x1280 2.2ms
# Speed: 34.4ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 46: 720x1280 2.2ms
# Speed: 33.0ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 47: 720x1280 2.2ms
# Speed: 39.1ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 48: 720x1280 2.2ms
# Speed: 38.8ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 49: 720x1280 2.3ms
# Speed: 40.3ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 50: 720x1280 2.3ms
# Speed: 35.8ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 51: 720x1280 2.6ms
# Speed: 35.8ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 52: 720x1280 2.6ms
# Speed: 36.2ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 53: 720x1280 2.6ms
# Speed: 41.0ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 54: 720x1280 2.8ms
# Speed: 39.9ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 55: 720x1280 2.5ms
# Speed: 44.1ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 56: 720x1280 2.5ms
# Speed: 36.4ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 57: 720x1280 2.6ms
# Speed: 46.1ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 58: 720x1280 2.6ms
# Speed: 33.8ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 59: 720x1280 2.4ms
# Speed: 40.9ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 60: 720x1280 2.4ms
# Speed: 36.8ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 61: 720x1280 2.2ms
# Speed: 35.8ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 62: 720x1280 2.2ms
# Speed: 32.6ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 63: 720x1280 2.0ms
# Speed: 33.6ms track, 2.0ms solution per image at shape (1, 3, 720, 1280)
#
# 64: 720x1280 2.9ms
# Speed: 35.2ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 65: 720x1280 2.6ms
# Speed: 38.4ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 66: 720x1280 2.4ms
# Speed: 37.1ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 67: 720x1280 2.2ms
# Speed: 39.4ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 68: 720x1280 2.2ms
# Speed: 34.2ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 69: 720x1280 2.3ms
# Speed: 33.4ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 70: 720x1280 2.4ms
# Speed: 33.2ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 71: 720x1280 2.3ms
# Speed: 39.5ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 72: 720x1280 2.7ms
# Speed: 42.0ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 73: 720x1280 2.2ms
# Speed: 38.7ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 74: 720x1280 2.2ms
# Speed: 32.3ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 75: 720x1280 2.0ms
# Speed: 31.5ms track, 2.0ms solution per image at shape (1, 3, 720, 1280)
#
# 76: 720x1280 2.2ms
# Speed: 35.0ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 77: 720x1280 2.6ms
# Speed: 45.9ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 78: 720x1280 3.2ms
# Speed: 49.5ms track, 3.2ms solution per image at shape (1, 3, 720, 1280)
#
# 79: 720x1280 2.0ms
# Speed: 36.6ms track, 2.0ms solution per image at shape (1, 3, 720, 1280)
#
# 80: 720x1280 1.9ms
# Speed: 34.2ms track, 1.9ms solution per image at shape (1, 3, 720, 1280)
#
# 81: 720x1280 1.9ms
# Speed: 32.7ms track, 1.9ms solution per image at shape (1, 3, 720, 1280)
#
# 82: 720x1280 2.2ms
# Speed: 32.9ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 83: 720x1280 2.4ms
# Speed: 39.8ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 84: 720x1280 2.3ms
# Speed: 39.1ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 85: 720x1280 2.2ms
# Speed: 37.9ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 86: 720x1280 2.1ms
# Speed: 33.0ms track, 2.1ms solution per image at shape (1, 3, 720, 1280)
#
# 87: 720x1280 2.2ms
# Speed: 31.9ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 88: 720x1280 2.2ms
# Speed: 33.3ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 89: 720x1280 3.0ms
# Speed: 53.9ms track, 3.0ms solution per image at shape (1, 3, 720, 1280)
#
# 90: 720x1280 2.8ms
# Speed: 61.2ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 91: 720x1280 2.8ms
# Speed: 55.0ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 92: 720x1280 3.1ms
# Speed: 49.9ms track, 3.1ms solution per image at shape (1, 3, 720, 1280)
#
# 93: 720x1280 2.9ms
# Speed: 48.1ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 94: 720x1280 2.9ms
# Speed: 53.9ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 95: 720x1280 2.7ms
# Speed: 60.8ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 96: 720x1280 2.8ms
# Speed: 57.9ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 97: 720x1280 3.2ms
# Speed: 60.0ms track, 3.2ms solution per image at shape (1, 3, 720, 1280)
#
# 98: 720x1280 2.9ms
# Speed: 49.0ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 99: 720x1280 3.0ms
# Speed: 46.8ms track, 3.0ms solution per image at shape (1, 3, 720, 1280)
#
# 100: 720x1280 2.9ms
# Speed: 51.4ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 101: 720x1280 3.1ms
# Speed: 59.8ms track, 3.1ms solution per image at shape (1, 3, 720, 1280)
#
# 102: 720x1280 3.0ms
# Speed: 59.9ms track, 3.0ms solution per image at shape (1, 3, 720, 1280)
#
# 103: 720x1280 2.7ms
# Speed: 57.3ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 104: 720x1280 2.8ms
# Speed: 50.0ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 105: 720x1280 3.0ms
# Speed: 50.3ms track, 3.0ms solution per image at shape (1, 3, 720, 1280)
#
# 106: 720x1280 2.8ms
# Speed: 51.2ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 107: 720x1280 2.9ms
# Speed: 61.1ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 108: 720x1280 2.9ms
# Speed: 55.9ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 109: 720x1280 3.2ms
# Speed: 61.0ms track, 3.2ms solution per image at shape (1, 3, 720, 1280)
#
# 110: 720x1280 2.9ms
# Speed: 61.7ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 111: 720x1280 3.1ms
# Speed: 49.0ms track, 3.1ms solution per image at shape (1, 3, 720, 1280)
#
# 112: 720x1280 3.0ms
# Speed: 48.0ms track, 3.0ms solution per image at shape (1, 3, 720, 1280)
#
# 113: 720x1280 2.6ms
# Speed: 57.0ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 114: 720x1280 2.8ms
# Speed: 60.2ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 115: 720x1280 3.1ms
# Speed: 60.0ms track, 3.1ms solution per image at shape (1, 3, 720, 1280)
#
# 116: 720x1280 3.3ms
# Speed: 51.8ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 117: 720x1280 3.3ms
# Speed: 50.3ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 118: 720x1280 3.5ms
# Speed: 53.3ms track, 3.5ms solution per image at shape (1, 3, 720, 1280)
#
# 119: 720x1280 2.9ms
# Speed: 59.9ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 120: 720x1280 3.2ms
# Speed: 50.2ms track, 3.2ms solution per image at shape (1, 3, 720, 1280)
#
# 121: 720x1280 2.8ms
# Speed: 57.3ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 122: 720x1280 2.9ms
# Speed: 60.5ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 123: 720x1280 2.8ms
# Speed: 52.8ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 124: 720x1280 2.8ms
# Speed: 53.9ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 125: 720x1280 3.3ms
# Speed: 59.6ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 126: 720x1280 2.9ms
# Speed: 60.7ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 127: 720x1280 3.0ms
# Speed: 58.6ms track, 3.0ms solution per image at shape (1, 3, 720, 1280)
#
# 128: 720x1280 3.0ms
# Speed: 62.9ms track, 3.0ms solution per image at shape (1, 3, 720, 1280)
#
# 129: 720x1280 3.2ms
# Speed: 58.6ms track, 3.2ms solution per image at shape (1, 3, 720, 1280)
#
# 130: 720x1280 3.1ms
# Speed: 56.8ms track, 3.1ms solution per image at shape (1, 3, 720, 1280)
#
# 131: 720x1280 3.2ms
# Speed: 52.7ms track, 3.2ms solution per image at shape (1, 3, 720, 1280)
#
# 132: 720x1280 3.0ms
# Speed: 63.5ms track, 3.0ms solution per image at shape (1, 3, 720, 1280)
#
# 133: 720x1280 2.9ms
# Speed: 61.1ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 134: 720x1280 5.2ms
# Speed: 67.5ms track, 5.2ms solution per image at shape (1, 3, 720, 1280)
#
# 135: 720x1280 2.6ms
# Speed: 49.6ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 136: 720x1280 2.0ms
# Speed: 34.6ms track, 2.0ms solution per image at shape (1, 3, 720, 1280)
#
# 137: 720x1280 2.4ms
# Speed: 34.6ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 138: 720x1280 2.4ms
# Speed: 38.4ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 139: 720x1280 2.4ms
# Speed: 37.8ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 140: 720x1280 3.2ms
# Speed: 55.7ms track, 3.2ms solution per image at shape (1, 3, 720, 1280)
#
# 141: 720x1280 2.2ms
# Speed: 53.8ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 142: 720x1280 2.0ms
# Speed: 33.9ms track, 2.0ms solution per image at shape (1, 3, 720, 1280)
#
# 143: 720x1280 2.6ms
# Speed: 33.0ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 144: 720x1280 2.2ms
# Speed: 39.8ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 145: 720x1280 2.2ms
# Speed: 38.4ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 146: 720x1280 2.1ms
# Speed: 36.3ms track, 2.1ms solution per image at shape (1, 3, 720, 1280)
#
# 147: 720x1280 2.3ms
# Speed: 34.2ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 148: 720x1280 2.2ms
# Speed: 34.7ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 149: 720x1280 2.3ms
# Speed: 32.1ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 150: 720x1280 2.3ms
# Speed: 39.8ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 151: 720x1280 2.5ms
# Speed: 36.8ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 152: 720x1280 2.1ms
# Speed: 36.0ms track, 2.1ms solution per image at shape (1, 3, 720, 1280)
#
# 153: 720x1280 2.3ms
# Speed: 35.4ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 154: 720x1280 2.3ms
# Speed: 35.3ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 155: 720x1280 2.7ms
# Speed: 35.5ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 156: 720x1280 2.5ms
# Speed: 40.1ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 157: 720x1280 2.6ms
# Speed: 37.5ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 158: 720x1280 2.1ms
# Speed: 37.2ms track, 2.1ms solution per image at shape (1, 3, 720, 1280)
#
# 159: 720x1280 2.1ms
# Speed: 31.4ms track, 2.1ms solution per image at shape (1, 3, 720, 1280)
#
# 160: 720x1280 2.4ms
# Speed: 32.0ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 161: 720x1280 7.1ms
# Speed: 45.5ms track, 7.1ms solution per image at shape (1, 3, 720, 1280)
#
# 162: 720x1280 2.3ms
# Speed: 37.4ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 163: 720x1280 2.2ms
# Speed: 36.7ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 164: 720x1280 2.4ms
# Speed: 36.4ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 165: 720x1280 2.3ms
# Speed: 34.4ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 166: 720x1280 2.1ms
# Speed: 33.6ms track, 2.1ms solution per image at shape (1, 3, 720, 1280)
#
# 167: 720x1280 2.3ms
# Speed: 34.3ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 168: 720x1280 2.7ms
# Speed: 40.5ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 169: 720x1280 2.6ms
# Speed: 37.5ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 170: 720x1280 2.3ms
# Speed: 44.5ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 171: 720x1280 2.1ms
# Speed: 35.0ms track, 2.1ms solution per image at shape (1, 3, 720, 1280)
#
# 172: 720x1280 2.2ms
# Speed: 32.6ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 173: 720x1280 2.3ms
# Speed: 31.9ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 174: 720x1280 2.5ms
# Speed: 38.8ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 175: 720x1280 2.6ms
# Speed: 39.4ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 176: 720x1280 2.6ms
# Speed: 37.9ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 177: 720x1280 2.3ms
# Speed: 34.6ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 178: 720x1280 2.4ms
# Speed: 36.1ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 179: 720x1280 2.3ms
# Speed: 34.6ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 180: 720x1280 2.5ms
# Speed: 40.1ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 181: 720x1280 2.4ms
# Speed: 37.0ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 182: 720x1280 3.1ms
# Speed: 50.9ms track, 3.1ms solution per image at shape (1, 3, 720, 1280)
#
# 183: 720x1280 2.4ms
# Speed: 37.1ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 184: 720x1280 2.4ms
# Speed: 35.2ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
#
ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 336: 720x1280 4.0ms
# Speed: 52.2ms track, 4.0ms solution per image at shape (1, 3, 720, 1280)
#
# 337: 720x1280 3.4ms
# Speed: 66.2ms track, 3.4ms solution per image at shape (1, 3, 720, 1280)
#
# 338: 720x1280 3.7ms
# Speed: 59.4ms track, 3.7ms solution per image at shape (1, 3, 720, 1280)
#
# 339: 720x1280 3.8ms
# Speed: 56.6ms track, 3.8ms solution per image at shape (1, 3, 720, 1280)
#
# 340: 720x1280 3.9ms
# Speed: 56.8ms track, 3.9ms solution per image at shape (1, 3, 720, 1280)
#
# 341: 720x1280 3.7ms
# Speed: 52.1ms track, 3.7ms solution per image at shape (1, 3, 720, 1280)
#
# 342: 720x1280 4.3ms
# Speed: 65.3ms track, 4.3ms solution per image at shape (1, 3, 720, 1280)
#
# 343: 720x1280 4.9ms
# Speed: 65.9ms track, 4.9ms solution per image at shape (1, 3, 720, 1280)
#
# 344: 720x1280 8.1ms
# Speed: 68.1ms track, 8.1ms solution per image at shape (1, 3, 720, 1280)
#
# 345: 720x1280 3.7ms
# Speed: 55.2ms track, 3.7ms solution per image at shape (1, 3, 720, 1280)
#
# 346: 720x1280 3.6ms
# Speed: 54.6ms track, 3.6ms solution per image at shape (1, 3, 720, 1280)
#
# 347: 720x1280 3.5ms
# Speed: 51.0ms track, 3.5ms solution per image at shape (1, 3, 720, 1280)
#
# 348: 720x1280 3.4ms
# Speed: 62.1ms track, 3.4ms solution per image at shape (1, 3, 720, 1280)
#
# 349: 720x1280 3.3ms
# Speed: 58.8ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 350: 720x1280 3.1ms
# Speed: 58.9ms track, 3.1ms solution per image at shape (1, 3, 720, 1280)
#
# 351: 720x1280 3.5ms
# Speed: 52.0ms track, 3.5ms solution per image at shape (1, 3, 720, 1280)
#
# 352: 720x1280 4.2ms
# Speed: 54.7ms track, 4.2ms solution per image at shape (1, 3, 720, 1280)
#
# 353: 720x1280 3.4ms
# Speed: 51.9ms track, 3.4ms solution per image at shape (1, 3, 720, 1280)
#
# 354: 720x1280 3.2ms
# Speed: 60.9ms track, 3.2ms solution per image at shape (1, 3, 720, 1280)
#
# 355: 720x1280 3.4ms
# Speed: 59.6ms track, 3.4ms solution per image at shape (1, 3, 720, 1280)
#
# 356: 720x1280 3.3ms
# Speed: 58.1ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 357: 720x1280 3.3ms
# Speed: 50.8ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 358: 720x1280 3.3ms
# Speed: 59.2ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 359: 720x1280 3.4ms
# Speed: 66.4ms track, 3.4ms solution per image at shape (1, 3, 720, 1280)
#
# 360: 720x1280 3.3ms
# Speed: 61.7ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 361: 720x1280 3.1ms
# Speed: 53.9ms track, 3.1ms solution per image at shape (1, 3, 720, 1280)
#
# 362: 720x1280 3.3ms
# Speed: 55.8ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 363: 720x1280 3.3ms
# Speed: 49.4ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 364: 720x1280 3.1ms
# Speed: 48.5ms track, 3.1ms solution per image at shape (1, 3, 720, 1280)
#
# 365: 720x1280 3.4ms
# Speed: 53.3ms track, 3.4ms solution per image at shape (1, 3, 720, 1280)
#
# 366: 720x1280 3.5ms
# Speed: 66.5ms track, 3.5ms solution per image at shape (1, 3, 720, 1280)
#
# 367: 720x1280 3.4ms
# Speed: 59.6ms track, 3.4ms solution per image at shape (1, 3, 720, 1280)
#
# 368: 720x1280 3.2ms
# Speed: 57.9ms track, 3.2ms solution per image at shape (1, 3, 720, 1280)
#
# 369: 720x1280 3.3ms
# Speed: 53.8ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 370: 720x1280 3.0ms
# Speed: 49.2ms track, 3.0ms solution per image at shape (1, 3, 720, 1280)
#
# 371: 720x1280 3.2ms
# Speed: 50.6ms track, 3.2ms solution per image at shape (1, 3, 720, 1280)
#
# 372: 720x1280 3.5ms
# Speed: 64.4ms track, 3.5ms solution per image at shape (1, 3, 720, 1280)
#
# 373: 720x1280 6.8ms
# Speed: 70.9ms track, 6.8ms solution per image at shape (1, 3, 720, 1280)
#
# 374: 720x1280 4.3ms
# Speed: 64.4ms track, 4.3ms solution per image at shape (1, 3, 720, 1280)
#
# 375: 720x1280 3.4ms
# Speed: 54.7ms track, 3.4ms solution per image at shape (1, 3, 720, 1280)
#
# 376: 720x1280 4.1ms
# Speed: 58.2ms track, 4.1ms solution per image at shape (1, 3, 720, 1280)
#
# 377: 720x1280 3.5ms
# Speed: 49.2ms track, 3.5ms solution per image at shape (1, 3, 720, 1280)
#
# 378: 720x1280 3.3ms
# Speed: 63.3ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 379: 720x1280 3.3ms
# Speed: 68.8ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 380: 720x1280 3.3ms
# Speed: 65.4ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 381: 720x1280 3.2ms
# Speed: 55.5ms track, 3.2ms solution per image at shape (1, 3, 720, 1280)
#
# 382: 720x1280 3.2ms
# Speed: 54.9ms track, 3.2ms solution per image at shape (1, 3, 720, 1280)
#
# 383: 720x1280 3.1ms
# Speed: 54.8ms track, 3.1ms solution per image at shape (1, 3, 720, 1280)
#
# 384: 720x1280 2.3ms
# Speed: 59.1ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 385: 720x1280 2.3ms
# Speed: 39.9ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 386: 720x1280 1.9ms
# Speed: 35.7ms track, 1.9ms solution per image at shape (1, 3, 720, 1280)
#
# 387: 720x1280 2.4ms
# Speed: 44.4ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 388: 720x1280 1.9ms
# Speed: 31.6ms track, 1.9ms solution per image at shape (1, 3, 720, 1280)
#
# 389: 720x1280 2.1ms
# Speed: 33.2ms track, 2.1ms solution per image at shape (1, 3, 720, 1280)
#
# 390: 720x1280 2.2ms
# Speed: 36.3ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 391: 720x1280 2.6ms
# Speed: 36.0ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 392: 720x1280 2.3ms
# Speed: 39.3ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 393: 720x1280 2.4ms
# Speed: 34.6ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 394: 720x1280 2.4ms
# Speed: 32.5ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 395: 720x1280 2.4ms
# Speed: 33.0ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 396: 720x1280 2.6ms
# Speed: 39.6ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 397: 720x1280 2.7ms
# Speed: 40.5ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 398: 720x1280 2.3ms
# Speed: 38.0ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 399: 720x1280 3.1ms
# Speed: 36.1ms track, 3.1ms solution per image at shape (1, 3, 720, 1280)
#
# 400: 720x1280 2.3ms
# Speed: 34.5ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 401: 720x1280 3.6ms
# Speed: 36.7ms track, 3.6ms solution per image at shape (1, 3, 720, 1280)
#
# 402: 720x1280 2.7ms
# Speed: 45.0ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 403: 720x1280 2.6ms
# Speed: 42.0ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 404: 720x1280 2.6ms
# Speed: 39.6ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 405: 720x1280 3.0ms
# Speed: 37.7ms track, 3.0ms solution per image at shape (1, 3, 720, 1280)
#
# 406: 720x1280 2.4ms
# Speed: 35.2ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 407: 720x1280 2.5ms
# Speed: 34.2ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 408: 720x1280 2.5ms
# Speed: 53.1ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 409: 720x1280 2.6ms
# Speed: 39.1ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 410: 720x1280 3.0ms
# Speed: 38.1ms track, 3.0ms solution per image at shape (1, 3, 720, 1280)
#
# 411: 720x1280 3.4ms
# Speed: 40.3ms track, 3.4ms solution per image at shape (1, 3, 720, 1280)
#
# 412: 720x1280 2.1ms
# Speed: 36.5ms track, 2.1ms solution per image at shape (1, 3, 720, 1280)
#
# 413: 720x1280 3.0ms
# Speed: 36.8ms track, 3.0ms solution per image at shape (1, 3, 720, 1280)
#
# 414: 720x1280 2.5ms
# Speed: 36.9ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 415: 720x1280 2.7ms
# Speed: 36.5ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 416: 720x1280 2.3ms
# Speed: 37.3ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 417: 720x1280 3.3ms
# Speed: 38.5ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 418: 720x1280 2.3ms
# Speed: 33.8ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 419: 720x1280 2.7ms
# Speed: 33.1ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 420: 720x1280 3.4ms
# Speed: 40.1ms track, 3.4ms solution per image at shape (1, 3, 720, 1280)
#
# 421: 720x1280 2.4ms
# Speed: 40.0ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 422: 720x1280 2.4ms
# Speed: 40.4ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 423: 720x1280 3.6ms
# Speed: 37.7ms track, 3.6ms solution per image at shape (1, 3, 720, 1280)
#
# 424: 720x1280 2.6ms
# Speed: 38.4ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 425: 720x1280 2.3ms
# Speed: 38.5ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 426: 720x1280 2.5ms
# Speed: 35.3ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 427: 720x1280 4.1ms
# Speed: 39.2ms track, 4.1ms solution per image at shape (1, 3, 720, 1280)
#
# 428: 720x1280 3.2ms
# Speed: 56.1ms track, 3.2ms solution per image at shape (1, 3, 720, 1280)
#
# 429: 720x1280 2.2ms
# Speed: 34.9ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 430: 720x1280 2.5ms
# Speed: 36.2ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 431: 720x1280 2.8ms
# Speed: 41.3ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 432: 720x1280 3.3ms
# Speed: 38.5ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 433: 720x1280 2.5ms
# Speed: 38.6ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 434: 720x1280 2.3ms
# Speed: 37.6ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 435: 720x1280 2.3ms
# Speed: 33.7ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 436: 720x1280 2.5ms
# Speed: 35.1ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 437: 720x1280 2.7ms
# Speed: 40.7ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
#
ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 491: 720x1280 2.7ms
# Speed: 41.6ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 492: 720x1280 2.6ms
# Speed: 37.1ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 493: 720x1280 2.7ms
# Speed: 38.7ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 494: 720x1280 2.7ms
# Speed: 38.9ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 495: 720x1280 2.4ms
# Speed: 35.8ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 496: 720x1280 2.7ms
# Speed: 34.8ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 497: 720x1280 3.2ms
# Speed: 43.8ms track, 3.2ms solution per image at shape (1, 3, 720, 1280)
#
# 498: 720x1280 2.8ms
# Speed: 34.4ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 499: 720x1280 2.7ms
# Speed: 41.7ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 500: 720x1280 2.5ms
# Speed: 39.9ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 501: 720x1280 2.9ms
# Speed: 36.1ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 502: 720x1280 2.8ms
# Speed: 34.1ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 503: 720x1280 4.1ms
# Speed: 46.6ms track, 4.1ms solution per image at shape (1, 3, 720, 1280)
#
# 504: 720x1280 2.7ms
# Speed: 36.0ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 505: 720x1280 3.2ms
# Speed: 40.0ms track, 3.2ms solution per image at shape (1, 3, 720, 1280)
#
# 506: 720x1280 2.8ms
# Speed: 39.2ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 507: 720x1280 2.5ms
# Speed: 35.4ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 508: 720x1280 3.1ms
# Speed: 43.1ms track, 3.1ms solution per image at shape (1, 3, 720, 1280)
#
# 509: 720x1280 2.8ms
# Speed: 57.0ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 510: 720x1280 3.0ms
# Speed: 35.4ms track, 3.0ms solution per image at shape (1, 3, 720, 1280)
#
# 511: 720x1280 2.6ms
# Speed: 40.3ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 512: 720x1280 2.7ms
# Speed: 41.2ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 513: 720x1280 2.5ms
# Speed: 35.7ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 514: 720x1280 2.9ms
# Speed: 37.3ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 515: 720x1280 2.3ms
# Speed: 42.0ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 516: 720x1280 2.8ms
# Speed: 36.1ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 517: 720x1280 2.7ms
# Speed: 37.2ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 518: 720x1280 2.2ms
# Speed: 37.0ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 519: 720x1280 2.2ms
# Speed: 36.3ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 520: 720x1280 2.6ms
# Speed: 33.4ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 521: 720x1280 2.5ms
# Speed: 40.3ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 522: 720x1280 2.5ms
# Speed: 35.4ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 523: 720x1280 2.6ms
# Speed: 39.3ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 524: 720x1280 2.5ms
# Speed: 36.0ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 525: 720x1280 2.2ms
# Speed: 33.8ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 526: 720x1280 2.7ms
# Speed: 33.7ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 527: 720x1280 2.3ms
# Speed: 38.4ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 528: 720x1280 2.8ms
# Speed: 35.6ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 529: 720x1280 3.5ms
# Speed: 53.5ms track, 3.5ms solution per image at shape (1, 3, 720, 1280)
#
# 530: 720x1280 2.6ms
# Speed: 37.6ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 531: 720x1280 2.1ms
# Speed: 32.2ms track, 2.1ms solution per image at shape (1, 3, 720, 1280)
#
# 532: 720x1280 2.6ms
# Speed: 33.0ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 533: 720x1280 2.5ms
# Speed: 37.5ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 534: 720x1280 2.4ms
# Speed: 32.8ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 535: 720x1280 2.4ms
# Speed: 38.0ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 536: 720x1280 2.5ms
# Speed: 35.9ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 537: 720x1280 2.8ms
# Speed: 35.3ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 538: 720x1280 2.7ms
# Speed: 35.4ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 539: 720x1280 2.1ms
# Speed: 38.6ms track, 2.1ms solution per image at shape (1, 3, 720, 1280)
#
# 540: 720x1280 2.9ms
# Speed: 34.9ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 541: 720x1280 2.5ms
# Speed: 39.2ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 542: 720x1280 2.4ms
# Speed: 41.5ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 543: 720x1280 2.1ms
# Speed: 35.5ms track, 2.1ms solution per image at shape (1, 3, 720, 1280)
#
# 544: 720x1280 2.7ms
# Speed: 32.3ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 545: 720x1280 2.3ms
# Speed: 44.1ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 546: 720x1280 2.7ms
# Speed: 38.8ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 547: 720x1280 3.0ms
# Speed: 39.7ms track, 3.0ms solution per image at shape (1, 3, 720, 1280)
#
# 548: 720x1280 2.9ms
# Speed: 43.9ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 549: 720x1280 2.9ms
# Speed: 40.3ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 550: 720x1280 2.9ms
# Speed: 49.1ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 551: 720x1280 2.7ms
# Speed: 43.1ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 552: 720x1280 2.9ms
# Speed: 36.9ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 553: 720x1280 2.6ms
# Speed: 44.4ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 554: 720x1280 2.6ms
# Speed: 41.0ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 555: 720x1280 2.5ms
# ...
#
# 1544: 720x1280 3.9ms
# Speed: 55.8ms track, 3.9ms solution per image at shape (1, 3, 720, 1280)
#
# 1545: 720x1280 4.1ms
# Speed: 58.6ms track, 4.1ms solution per image at shape (1, 3, 720, 1280)
#
# 1546: 720x1280 3.9ms
# Speed: 58.9ms track, 3.9ms solution per image at shape (1, 3, 720, 1280)
#
# 1547: 720x1280 3.6ms
# Speed: 64.7ms track, 3.6ms solution per image at shape (1, 3, 720, 1280)
#
# 1548: 720x1280 3.8ms
# Speed: 66.8ms track, 3.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1549: 720x1280 3.7ms
# Speed: 52.2ms track, 3.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1550: 720x1280 3.8ms
# Speed: 52.1ms track, 3.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1551: 720x1280 3.8ms
# Speed: 52.9ms track, 3.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1552: 720x1280 3.6ms
# Speed: 58.7ms track, 3.6ms solution per image at shape (1, 3, 720, 1280)
#
# 1553: 720x1280 4.4ms
# Speed: 65.4ms track, 4.4ms solution per image at shape (1, 3, 720, 1280)
#
# 1554: 720x1280 3.9ms
# Speed: 62.9ms track, 3.9ms solution per image at shape (1, 3, 720, 1280)
#
# 1555: 720x1280 5.1ms
# Speed: 54.4ms track, 5.1ms solution per image at shape (1, 3, 720, 1280)
#
# 1556: 720x1280 4.3ms
# Speed: 63.6ms track, 4.3ms solution per image at shape (1, 3, 720, 1280)
#
# 1557: 720x1280 3.7ms
# Speed: 66.3ms track, 3.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1558: 720x1280 3.6ms
# Speed: 61.1ms track, 3.6ms solution per image at shape (1, 3, 720, 1280)
#
# 1559: 720x1280 3.3ms
# Speed: 64.8ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 1560: 720x1280 3.2ms
# Speed: 58.5ms track, 3.2ms solution per image at shape (1, 3, 720, 1280)
#
# 1561: 720x1280 3.8ms
# Speed: 51.3ms track, 3.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1562: 720x1280 3.3ms
# Speed: 50.2ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 1563: 720x1280 5.6ms
# Speed: 56.3ms track, 5.6ms solution per image at shape (1, 3, 720, 1280)
#
# 1564: 720x1280 3.5ms
# Speed: 64.9ms track, 3.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1565: 720x1280 3.2ms
# Speed: 61.8ms track, 3.2ms solution per image at shape (1, 3, 720, 1280)
#
# 1566: 720x1280 3.5ms
# Speed: 58.8ms track, 3.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1567: 720x1280 3.3ms
# Speed: 51.0ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 1568: 720x1280 3.5ms
# Speed: 50.9ms track, 3.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1569: 720x1280 3.9ms
# Speed: 53.1ms track, 3.9ms solution per image at shape (1, 3, 720, 1280)
#
# 1570: 720x1280 3.3ms
# Speed: 61.0ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 1571: 720x1280 3.5ms
# Speed: 64.6ms track, 3.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1572: 720x1280 3.8ms
# Speed: 62.2ms track, 3.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1573: 720x1280 3.9ms
# Speed: 55.5ms track, 3.9ms solution per image at shape (1, 3, 720, 1280)
#
# 1574: 720x1280 3.8ms
# Speed: 51.1ms track, 3.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1575: 720x1280 3.3ms
# Speed: 57.1ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 1576: 720x1280 4.7ms
# Speed: 60.2ms track, 4.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1577: 720x1280 3.4ms
# Speed: 66.3ms track, 3.4ms solution per image at shape (1, 3, 720, 1280)
#
# 1578: 720x1280 3.5ms
# Speed: 58.9ms track, 3.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1579: 720x1280 3.6ms
# Speed: 59.0ms track, 3.6ms solution per image at shape (1, 3, 720, 1280)
#
# 1580: 720x1280 3.4ms
# Speed: 58.6ms track, 3.4ms solution per image at shape (1, 3, 720, 1280)
#
# 1581: 720x1280 4.2ms
# Speed: 66.9ms track, 4.2ms solution per image at shape (1, 3, 720, 1280)
#
# 1582: 720x1280 3.8ms
# Speed: 68.9ms track, 3.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1583: 720x1280 3.7ms
# Speed: 70.5ms track, 3.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1584: 720x1280 3.9ms
# Speed: 78.8ms track, 3.9ms solution per image at shape (1, 3, 720, 1280)
#
# 1585: 720x1280 3.7ms
# Speed: 51.1ms track, 3.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1586: 720x1280 4.7ms
# Speed: 60.7ms track, 4.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1587: 720x1280 3.3ms
# Speed: 54.4ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 1588: 720x1280 5.6ms
# Speed: 61.4ms track, 5.6ms solution per image at shape (1, 3, 720, 1280)
#
# 1589: 720x1280 3.2ms
# Speed: 74.5ms track, 3.2ms solution per image at shape (1, 3, 720, 1280)
#
# 1590: 720x1280 3.4ms
# Speed: 61.4ms track, 3.4ms solution per image at shape (1, 3, 720, 1280)
#
# 1591: 720x1280 3.8ms
# Speed: 59.3ms track, 3.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1592: 720x1280 2.9ms
# Speed: 38.1ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 1593: 720x1280 2.7ms
# Speed: 38.4ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1594: 720x1280 4.5ms
# Speed: 41.0ms track, 4.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1595: 720x1280 2.8ms
# Speed: 39.3ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1596: 720x1280 2.9ms
# Speed: 38.0ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 1597: 720x1280 2.9ms
# Speed: 35.8ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 1598: 720x1280 2.9ms
# Speed: 36.0ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 1599: 720x1280 3.7ms
# Speed: 45.3ms track, 3.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1600: 720x1280 2.9ms
# Speed: 41.5ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 1601: 720x1280 2.8ms
# Speed: 41.3ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1602: 720x1280 2.8ms
# Speed: 41.0ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1603: 720x1280 2.8ms
# Speed: 35.4ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1604: 720x1280 2.6ms
# Speed: 36.0ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 1605: 720x1280 2.9ms
# Speed: 35.6ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 1606: 720x1280 3.1ms
# Speed: 41.1ms track, 3.1ms solution per image at shape (1, 3, 720, 1280)
#
# 1607: 720x1280 2.8ms
# Speed: 41.0ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1608: 720x1280 2.8ms
# Speed: 39.6ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1609: 720x1280 2.3ms
# Speed: 35.8ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 1610: 720x1280 2.8ms
# Speed: 34.5ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1611: 720x1280 3.0ms
# Speed: 39.2ms track, 3.0ms solution per image at shape (1, 3, 720, 1280)
#
# 1612: 720x1280 3.1ms
# Speed: 39.1ms track, 3.1ms solution per image at shape (1, 3, 720, 1280)
#
# 1613: 720x1280 2.9ms
# Speed: 43.4ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 1614: 720x1280 3.0ms
# Speed: 41.7ms track, 3.0ms solution per image at shape (1, 3, 720, 1280)
#
# 1615: 720x1280 2.3ms
# Speed: 34.8ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 1616: 720x1280 2.7ms
# Speed: 35.4ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1617: 720x1280 2.8ms
# Speed: 35.2ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1618: 720x1280 2.5ms
# Speed: 38.8ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1619: 720x1280 2.5ms
# Speed: 49.5ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1620: 720x1280 2.7ms
# Speed: 38.5ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1621: 720x1280 2.7ms
# Speed: 38.5ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1622: 720x1280 2.6ms
# Speed: 35.8ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 1623: 720x1280 3.0ms
# Speed: 35.7ms track, 3.0ms solution per image at shape (1, 3, 720, 1280)
#
# 1624: 720x1280 2.8ms
# Speed: 39.1ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1625: 720x1280 2.6ms
# Speed: 40.9ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 1626: 720x1280 2.5ms
# Speed: 36.0ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1627: 720x1280 3.0ms
# Speed: 40.6ms track, 3.0ms solution per image at shape (1, 3, 720, 1280)
#
# 1628: 720x1280 2.7ms
# Speed: 35.4ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1629: 720x1280 2.5ms
# Speed: 33.9ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1630: 720x1280 2.6ms
# Speed: 35.8ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 1631: 720x1280 2.8ms
# Speed: 44.7ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1632: 720x1280 2.8ms
# Speed: 44.7ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1633: 720x1280 2.8ms
# Speed: 43.5ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1634: 720x1280 2.8ms
# Speed: 36.8ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1635: 720x1280 2.8ms
# Speed: 36.4ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1636: 720x1280 2.7ms
# Speed: 35.3ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1637: 720x1280 2.7ms
# Speed: 39.5ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1638: 720x1280 3.1ms
# Speed: 50.2ms track, 3.1ms solution per image at shape (1, 3, 720, 1280)
#
# 1639: 720x1280 3.4ms
# Speed: 39.4ms track, 3.4ms solution per image at shape (1, 3, 720, 1280)
#
# 1640: 720x1280 2.5ms
# Speed: 33.0ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1641: 720x1280 2.1ms
# Speed: 34.0ms track, 2.1ms solution per image at shape (1, 3, 720, 1280)
#
# 1642: 720x1280 2.4ms
# Speed: 35.0ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 1643: 720x1280 2.7ms
# Speed: 37.8ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1644: 720x1280 2.3ms
# Speed: 39.2ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 1645: 720x1280 2.6ms
# Speed: 40.3ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 1646: 720x1280 2.4ms
# Speed: 35.9ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 1647: 720x1280 4.0ms
# Speed: 42.5ms track, 4.0ms solution per image at shape (1, 3, 720, 1280)
#
# 1648: 720x1280 2.4ms
# Speed: 34.9ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 1649: 720x1280 2.4ms
# Speed: 39.7ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 1650: 720x1280 2.5ms
# Speed: 42.9ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1651: 720x1280 2.5ms
# Speed: 38.4ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1652: 720x1280 2.4ms
# Speed: 34.8ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 1653: 720x1280 2.8ms
# Speed: 36.8ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1654: 720x1280 2.8ms
# Speed: 35.6ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1655: 720x1280 2.7ms
# Speed: 42.2ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1656: 720x1280 2.5ms
# Speed: 43.1ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1657: 720x1280 2.5ms
# Speed: 38.6ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1658: 720x1280 3.6ms
# Speed: 44.5ms track, 3.6ms solution per image at shape (1, 3, 720, 1280)
#
# 1659: 720x1280 2.7ms
# Speed: 36.3ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1660: 720x1280 2.5ms
# Speed: 33.9ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1661: 720x1280 2.5ms
# Speed: 38.7ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1662: 720x1280 2.5ms
# Speed: 38.7ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1663: 720x1280 2.2ms
# Speed: 37.8ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 1664: 720x1280 2.3ms
# Speed: 35.2ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 1665: 720x1280 2.4ms
# Speed: 35.2ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 1666: 720x1280 2.5ms
# Speed: 33.9ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1667: 720x1280 2.5ms
# Speed: 38.0ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1668: 720x1280 2.5ms
# Speed: 43.6ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1669: 720x1280 2.7ms
# Speed: 39.6ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1670: 720x1280 2.8ms
# Speed: 34.0ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1671: 720x1280 2.2ms
# Speed: 34.4ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 1672: 720x1280 2.3ms
# Speed: 33.6ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 1673: 720x1280 2.4ms
# Speed: 40.7ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 1674: 720x1280 2.8ms
# Speed: 39.9ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1675: 720x1280 2.7ms
# Speed: 39.2ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1676: 720x1280 2.8ms
# Speed: 40.0ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1677: 720x1280 2.5ms
# Speed: 34.3ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1678: 720x1280 2.5ms
# Speed: 32.7ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1679: 720x1280 2.4ms
# Speed: 49.2ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 1680: 720x1280 2.6ms
# Speed: 38.3ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 1681: 720x1280 2.5ms
# Speed: 40.5ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1682: 720x1280 2.4ms
# Speed: 34.3ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 1683: 720x1280 2.4ms
# Speed: 36.2ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 1684: 720x1280 2.7ms
# Speed: 39.3ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1685: 720x1280 2.9ms
# Speed: 43.2ms track, 2.9ms solution per image at shape (1, 3, 720, 1280)
#
# 1686: 720x1280 2.4ms
# Speed: 40.0ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 1687: 720x1280 2.1ms
# Speed: 38.1ms track, 2.1ms solution per image at shape (1, 3, 720, 1280)
#
# 1688: 720x1280 2.3ms
# Speed: 36.8ms track, 2.3ms solution per image at shape (1, 3, 720, 1280)
#
# 1689: 720x1280 2.2ms
# Speed: 35.3ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 1690: 720x1280 2.7ms
# Speed: 34.6ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1691: 720x1280 2.6ms
# Speed: 38.5ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 1692: 720x1280 2.8ms
# Speed: 43.4ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1693: 720x1280 2.8ms
# Speed: 44.6ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1694: 720x1280 2.4ms
# Speed: 37.7ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 1695: 720x1280 2.7ms
# Speed: 41.3ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1696: 720x1280 2.5ms
# Speed: 34.4ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1697: 720x1280 2.5ms
# Speed: 37.9ms track, 2.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1698: 720x1280 3.3ms
# Speed: 54.9ms track, 3.3ms solution per image at shape (1, 3, 720, 1280)
#
# 1699: 720x1280 2.1ms
# Speed: 38.2ms track, 2.1ms solution per image at shape (1, 3, 720, 1280)
#
# 1700: 720x1280 2.2ms
# Speed: 34.3ms track, 2.2ms solution per image at shape (1, 3, 720, 1280)
#
# 1701: 720x1280 2.1ms
# Speed: 35.1ms track, 2.1ms solution per image at shape (1, 3, 720, 1280)
#
# 1702: 720x1280 2.8ms
# Speed: 36.9ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1703: 720x1280 2.4ms
# Speed: 43.9ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 1704: 720x1280 2.6ms
# Speed: 40.2ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 1705: 720x1280 2.6ms
# Speed: 40.1ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 1706: 720x1280 2.4ms
# Speed: 37.0ms track, 2.4ms solution per image at shape (1, 3, 720, 1280)
#
# 1707: 720x1280 2.7ms
# Speed: 35.3ms track, 2.7ms solution per image at shape (1, 3, 720, 1280)
#
# 1708: 720x1280 2.8ms
# Speed: 38.3ms track, 2.8ms solution per image at shape (1, 3, 720, 1280)
#
# 1709: 720x1280 2.6ms
# Speed: 41.5ms track, 2.6ms solution per image at shape (1, 3, 720, 1280)
#
# 1710: 720x1280 2.1ms
# Speed: 40.8ms track, 2.1ms solution per image at shape (1, 3, 720, 1280)
#
# Video frame is empty or video processing has been successfully completed.

# %%
from IPython.display import HTML
from base64 import b64encode
import os

def display_video(file_path):
  video_file = open(file_path, "r+b").read()
  video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
  return HTML(f"""
  <video width="640" height="480" controls>
    <source src="{video_url}" type="video/mp4">
  </video>
  """)

file_path = "/content/gdrive/MyDrive/IE/Notebooks_ObjectTracking/traffic.mp4"  # Replace with your video file path
display_video(file_path)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
