# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel('INSURANCE.xlsx')
df.head(5)
# Out:
#    CASEID  SATISF  prod_TYPE   AGE  FEMALE  PREV_ACCIDENT   PRICE  TIMEASCUST  \
# 0       1      10          3  18.0       1              0  1379.0           0
# 1       2       9          1  34.0       1              0   895.0          15
# 2       3       3          2  34.0       0              0   883.0           0
# 3       4       8          3  18.0       1              0  1412.0           0
# 4       5       8          2  18.0       1              0  1379.0           0
#
#    YEARSEXP  COMP  INCOME
# 0         0     2   29563
# 1        16     8   49690
# 2         0     3   34693
# 3         0     5   40710
# 4         0     2   31827

# %%
df.isna().sum()
# Out:
# CASEID           0
# SATISF           0
# prod_TYPE        0
# AGE              3
# FEMALE           0
# PREV_ACCIDENT    0
# PRICE            2
# TIMEASCUST       0
# YEARSEXP         0
# COMP             0
# INCOME           0
# dtype: int64

# %%
df['PRICE'].fillna(df['PRICE'].mean(), inplace=True)
df['PRICE'].isna().sum()
# Out:
# 0

# %%
import seaborn as sns

corr_matrix = df.corr()
sns.set(font_scale=0.6)
fig, ax = plt.subplots(figsize=(12,12))         
sns.heatmap(corr_matrix, annot=True, fmt=".2f", linewidths=1, ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# Need to standardize
