# %% [markdown]
# ## Optional Exercise 5: XOR PROBLEM
#
# Following the notebook S3_XOR_template.ipynb:
# 1) Create a neural net with topology 2 – 2 – 1 to solve the problem.
# 2) Once converged, plot the boundaries over the scatter plot of the data.

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn import datasets
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ### The XOR data

# %%
# We create four blobs with different centers to create the original data
centers = ([0, 0], [0, 5], [5, 0], [5, 5])
X, y = datasets.make_blobs(n_samples=400, centers = centers, cluster_std=0.8)
# Reduce the classes to two classe simulating the XOR problem 
y[y == 3] = 0
y[y == 2] = 1
# Plotting
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired)

# %% [markdown]
# ### Neural Network

# %%
neural_network = tf.keras.Sequential([
    layers.Input(shape = (2,), name = "Input"),
    layers.Dense(2, activation = "relu", name = "Hidden_Layer"),
    layers.Dense(1, activation = "sigmoid", name = "Output")]
)

# %%
neural_network.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden_Layer (Dense)            │ (None, 2)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
neural_network.compile(
    optimizer = "SGD",
    loss = "binary_crossentropy",
    metrics = ['accuracy']
)

# %% [markdown]
# ### Training With Early Stopping

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor = "val_loss",
    patience=15, 
    restore_best_weights = True
)

history = neural_network.fit(
    X, y,
    epochs=200,
    validation_split=0.2,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.6032 - loss: 1.0757 - val_accuracy: 0.4500 - val_loss: 0.7448
# Epoch 2/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4552 - loss: 0.7427 - val_accuracy: 0.5000 - val_loss: 0.7323
# Epoch 3/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5790 - loss: 0.7256 - val_accuracy: 0.5750 - val_loss: 0.7327
# Epoch 4/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6283 - loss: 0.7124 - val_accuracy: 0.6250 - val_loss: 0.7329
# Epoch 5/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7388 - loss: 0.7018 - val_accuracy: 0.6125 - val_loss: 0.7255
# Epoch 6/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6460 - loss: 0.7186 - val_accuracy: 0.6375 - val_loss: 0.7254
# Epoch 7/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6886 - loss: 0.7082 - val_accuracy: 0.6375 - val_loss: 0.7267
# Epoch 8/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7176 - loss: 0.6997 - val_accuracy: 0.6375 - val_loss: 0.7221
# Epoch 9/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7332 - loss: 0.6903 - val_accuracy: 0.6375 - val_loss: 0.7185
# Epoch 10/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7053 - loss: 0.6966 - val_accuracy: 0.6375 - val_loss: 0.7153
# Epoch 11/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7253 - loss: 0.6912 - val_accuracy: 0.6375 - val_loss: 0.7100
# Epoch 12/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7510 - loss: 0.6862 - val_accuracy: 0.6375 - val_loss: 0.7087
# Epoch 13/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6857 - loss: 0.6955 - val_accuracy: 0.6375 - val_loss: 0.7055
# Epoch 14/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6741 - loss: 0.6992 - val_accuracy: 0.6375 - val_loss: 0.7087
# Epoch 15/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7074 - loss: 0.6954 - val_accuracy: 0.6125 - val_loss: 0.7094
# Epoch 16/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6294 - loss: 0.6986 - val_accuracy: 0.5875 - val_loss: 0.7083
# Epoch 17/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6533 - loss: 0.6894 - val_accuracy: 0.6250 - val_loss: 0.7057
# Epoch 18/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6530 - loss: 0.6957 - val_accuracy: 0.5875 - val_loss: 0.7050
# Epoch 19/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5899 - loss: 0.6949 - val_accuracy: 0.6250 - val_loss: 0.7020
# Epoch 20/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6927 - loss: 0.6888 - val_accuracy: 0.5500 - val_loss: 0.7036
# Epoch 21/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5319 - loss: 0.6887 - val_accuracy: 0.6250 - val_loss: 0.6984
# Epoch 22/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.
200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4798 - loss: 0.6793 - val_accuracy: 0.6625 - val_loss: 0.6827
# Epoch 56/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5129 - loss: 0.6837 - val_accuracy: 0.6625 - val_loss: 0.6828
# Epoch 57/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5510 - loss: 0.6815 - val_accuracy: 0.6500 - val_loss: 0.6838
# Epoch 58/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4831 - loss: 0.6813 - val_accuracy: 0.6500 - val_loss: 0.6837
# Epoch 59/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4738 - loss: 0.6815 - val_accuracy: 0.7750 - val_loss: 0.6797
# Epoch 60/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6145 - loss: 0.6850 - val_accuracy: 0.4250 - val_loss: 0.6904
# Epoch 61/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4159 - loss: 0.6813 - val_accuracy: 0.5000 - val_loss: 0.6873
# Epoch 62/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5481 - loss: 0.6862 - val_accuracy: 0.3625 - val_loss: 0.6958
# Epoch 63/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4129 - loss: 0.6867 - val_accuracy: 0.3875 - val_loss: 0.6933
# Epoch 64/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4121 - loss: 0.6822 - val_accuracy: 0.4000 - val_loss: 0.6902
# Epoch 65/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4371 - loss: 0.6804 - val_accuracy: 0.4625 - val_loss: 0.6872
# Epoch 66/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4333 - loss: 0.6767 - val_accuracy: 0.5625 - val_loss: 0.6841
# Epoch 67/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6007 - loss: 0.6837 - val_accuracy: 0.3875 - val_loss: 0.6912
# Epoch 68/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4289 - loss: 0.6846 - val_accuracy: 0.3750 - val_loss: 0.6927
# Epoch 69/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3591 - loss: 0.6852 - val_accuracy: 0.4375 - val_loss: 0.6873
# Epoch 70/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6019 - loss: 0.6844 - val_accuracy: 0.3375 - val_loss: 0.6942
# Epoch 71/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3986 - loss: 0.6877 - val_accuracy: 0.3750 - val_loss: 0.6914
# Epoch 72/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4404 - loss: 0.6867 - val_accuracy: 0.3750 - val_loss: 0.6899
# Epoch 73/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4244 - loss: 0.6833 - val_accuracy: 0.4375 - val_loss: 0.6870
# Epoch 74/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4215 - loss: 0.6776 - val_accuracy: 0.6750 - val_loss: 0.6799

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, 1])
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)
plot_loss(history)

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training vs Validation Accuracy')
plt.show()

# %% [markdown]
# ### Plotting Boundaries

# %%
import numpy as np
# Create a grid of points over the input feature space
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.linspace(x_min, x_max, 300),
                     np.linspace(y_min, y_max, 300))

# Flatten the grid and stack as input for prediction
grid = np.c_[xx.ravel(), yy.ravel()]

# Predict probabilities for each point on the grid
preds = neural_network.predict(grid, verbose=0).reshape(xx.shape)

# Plot the decision boundary
plt.figure(figsize=(8, 6))
plt.contourf(xx, yy, preds, levels=[0, 0.5, 1], alpha=0.4, cmap=plt.cm.Paired)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired, edgecolors='k')
plt.title("Decision Boundary of XOR Neural Network")
plt.xlabel("X1")
plt.ylabel("X2")
plt.show()

# %%
plt.figure(figsize=(8, 6))

# Plot only the decision boundary (black line where prediction = 0.5)
plt.contour(xx, yy, probs, levels=[0.5], colors='black', linewidths=2)

# Plot the original data points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired, edgecolors='k')

plt.title("Decision Boundary of Neural Network (XOR-like Data)")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 4
#       1 plt.figure(figsize=(8, 6))
#       3 # Plot only the decision boundary (black line where prediction = 0.5)
# ----> 4 plt.contour(xx, yy, probs, levels=[0.5], colors='black', linewidths=2)
#       6 # Plot the original data points
#       7 plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired, edgecolors='k')
#
# NameError: name 'probs' is not defined
