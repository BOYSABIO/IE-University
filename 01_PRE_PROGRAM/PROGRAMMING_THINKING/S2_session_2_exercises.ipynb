# %% [markdown]
# # Session 2 Exercises
# To use this Sheet:
# 1. Navigate to `File`
# 2. Click `Save a copy in Drive`
# 3. Open `Copy of Session_2_Exercises.ipynb`

# %%
#@title <- Run the Play button on the left
# !pip3 install ColabTurtle
from ColabTurtle.Turtle import *
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7642 sha256=c6a33507f2ee1eea227603b0769934245e352345e401b9178c2daa99618cb9d8
#   Stored in directory: /root/.cache/pip/wheels/5b/86/e8/54f5c8c853606e3a3060bb2e60363cbed632374a12e0f33ffc
# Successfully built ColabTurtle
# ...

# %% [markdown]
# ## Short Documentation
# - `initializeTurtle()` -> Starts and Resets Turtle.
# - `forward(units)` -> Moves the turtle in the direction it is facing, by `units` pixels.
#
# - `right(degrees)` -> Turns the turtle to right by the given `degrees` many degrees.
#
# - `left(degrees)` -> Turns the turtle to left by the given `degrees` many degrees.

# %% [markdown]
# ### Exercise 1 - Draw 50 units.
# - Start a Turtle.
# - Create a line of 50 units.

# %% [markdown]
# ### Exercise 2 - Draw 50 units to the right.
# - Reset the Turtle.
# - Turn to right (how many degrees is that?)
# - Create a line of 50 units to the right.

# %% [markdown]
# ### Exercise 3 - Draw 50 units down.
# - Reset the Turtle.
# - Turn the Turtle to go down (how many degrees?)
# - Create a line of 50 units to go down.

# %% [markdown]
# ### Exercise 4 - Draw 50 units to the left.
# - Reset the Turtle.
# - Turn the Turtle to go to the left (how many degrees?)
# - Create a line of 50 units to the right.

# %% [markdown]
# ### Exercise 5 - Draw a Square of 50x50 units.
# - Reset the Turtle.
# - Write down the instructions  in Natural Language to draw square.
# - Draw a square in code.

# %% [markdown]
# ### Exercise 6 - Draw a Rectangle of 50x100 units.
# - Reset the Turtle.
# - Write down the instructions in Natural Language to draw the rectangle.
# - Draw the rectangle in code.

# %% [markdown]
# ### Exercise 6 - Draw a Triangle of 100 units.
# - Reset the Turtle.
# - Write down the instructions in Natural Language to draw a triangle.
# - Draw the triangle in code.

# %% [markdown]
# # Try to solve the following exercises at home!

# %% [markdown]
# ### Exercise 7 - Draw a Hexagon of 100 units.
# - Reset the Turtle.
# - Write down the instructions in Natural Language to draw a Hexagon.
# - Draw the Hexagon in code.

# %% [markdown]
# ## More complicated shapes

# %% [markdown]
# ### Exercise 8 - Draw a Diamond pattern of 100 units.
# Diamond pattern - a symmetrical diamond shape.
#
# - Reset the Turtle.
# - Write down the instructions in Natural Language to draw a Diamond pattern.
# - Draw the Diamond pattern in code.

# %% [markdown]
# ### Exercise 9 - Draw a Bow Tie pattern.
# Bow Tie pattern - two triangles connected from the top.
#
# - Reset the Turtle.
# - Write down the instructions in Natural Language to draw a Bow Tie pattern.
# - Draw the Bow Tie pattern in code.

# %% [markdown]
# ### Exercise 10 - Draw a 5-Star pattern.
# 5-Star pattern - a symmetrical shape with intersecting lines forming a star.
#
# - Reset the Turtle.
# - Write down the instructions in Natural Language to draw a 5-Star pattern.
# - Draw the 5-Star pattern in code.
