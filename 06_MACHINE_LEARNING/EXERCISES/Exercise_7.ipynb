# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import graphviz

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor 

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
data = pd.read_csv('../DATA/GlaucomaM.csv')
data.head()
# Out:
#       ag     at     as     an     ai    eag    eat    eas    ean    eai  ...  \
# 0  2.220  0.354  0.580  0.686  0.601  1.267  0.336  0.346  0.255  0.331  ...
# 1  2.681  0.475  0.672  0.868  0.667  2.053  0.440  0.520  0.639  0.454  ...
# 2  1.979  0.343  0.508  0.624  0.504  1.200  0.299  0.396  0.259  0.246  ...
# 3  1.747  0.269  0.476  0.525  0.476  0.612  0.147  0.017  0.044  0.405  ...
# 4  2.990  0.599  0.686  1.039  0.667  2.513  0.543  0.607  0.871  0.492  ...
#
#      tmt    tms    tmn    tmi     mr    rnf   mdic    emd     mv   Class
# 0 -0.018 -0.230 -0.510 -0.158  0.841  0.410  0.137  0.239  0.035  normal
# 1 -0.014 -0.165 -0.317 -0.192  0.924  0.256  0.252  0.329  0.022  normal
# 2 -0.097 -0.235 -0.337 -0.020  0.795  0.378  0.152  0.250  0.029  normal
# 3 -0.035 -0.449 -0.217 -0.091  0.746  0.200  0.027  0.078  0.023  normal
# 4 -0.105  0.084 -0.012 -0.054  0.977  0.193  0.297  0.354  0.034  normal
#
# [5 rows x 63 columns]

# %%
data['Class'].value_counts()
# Out:
# Class
# normal      98
# glaucoma    98
# Name: count, dtype: int64

# %%
data['Class'] = data['Class'].map({'glaucoma': 1, 'normal': 0})

# %%
data.isna().sum()
# Out:
# ag       0
# at       0
# as       0
# an       0
# ai       0
#         ..
# rnf      0
# mdic     0
# emd      0
# mv       0
# Class    0
# Length: 63, dtype: int64

# %%
data.describe()
# Out:
#                ag          at          as          an          ai         eag  \
# count  196.000000  196.000000  196.000000  196.000000  196.000000  196.000000
# mean     2.606531    0.458980    0.651781    0.835929    0.659995    1.874138
# std      0.659789    0.127013    0.158462    0.222166    0.161065    0.721218
# min      1.312000    0.201000    0.345000    0.397000    0.369000    0.415000
# 25%      2.139250    0.370750    0.538500    0.681000    0.550500    1.309250
# 50%      2.533000    0.444500    0.630500    0.808500    0.632000    1.843500
# 75%      2.943500    0.528000    0.738250    0.952000    0.749750    2.317000
# max      5.444000    0.967000    1.340000    1.765000    1.373000    4.125000
#
#               eat         eas         ean         eai  ...         tmt  \
# count  196.000000  196.000000  196.000000  196.000000  ...  196.000000
# mean     0.406372    0.486403    0.501214    0.480097  ...   -0.004658
# std      0.125941    0.184486    0.286181    0.173977  ...    0.128062
# min      0.137000    0.017000    0.008000    0.098000  ...   -0.291000
# 25%      0.315750    0.380750    0.280500    0.372500  ...   -0.101000
# 50%      0.402500    0.468500    0.503500    0.484000  ...   -0.018500
# 75%      0.483250    0.605500    0.689500    0.594750  ...    0.087750
# max      0.848000    1.225000    1.568000    0.961000  ...    0.366000
#
#               tms         tmn         tmi          mr         rnf        mdic  \
# count  196.000000  196.000000  196.000000  196.000000  196.000000  196.000000
# mean    -0.039806   -0.147204   -0.036510    0.904985    0.182383    0.231270
# std      0.150077    0.134205    0.136423    0.112356    0.094080    0.123882
# min     -0.449000   -0.510000   -0.405000    0.647000   -0.297000    0.012000
# 25%     -0.135250   -0.231000   -0.127500    0.826000    0.119750    0.144000
# 50%     -0.031500   -0.146500   -0.036000    0.899500    0.182000    0.227000
# 75%      0.068000   -0.056250    0.049500    0.968500    0.237000    0.299250
# max      0.358000    0.245000    0.418000    1.317000    0.451000    0.663000
#
#               emd          mv      Class
# count  196.000000  196.000000  196.00000
# mean     0.308903    0.033541    0.50000
# std      0.128246    0.021850    0.50128
# min      0.047000    0.000000    0.00000
# 25%      0.230500    0.021000    0.00000
# 50%      0.298000    0.028000    0.50000
# 75%      0.379250    0.038250    1.00000
# max      0.743000    0.183000    1.00000
#
# [8 rows x 63 columns]

# %%
x, y = data.iloc[:, :-1], data.iloc[:, -1]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.5, random_state = 123)

# %%
rf = RandomForestRegressor(n_estimators = 200, random_state=123)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=123)

# %%
rf_pred_tr = rf.predict(x_train)
rf_pred_ts = rf.predict(x_test)
rmse_train = mean_squared_error(y_train, rf_pred_tr)**(1/2)
rmse_test = mean_squared_error(y_test, rf_pred_ts)**(1/2)
print("Train set RMSE: %f " % (rmse_train))
print("Test set RMSE: %f " % (rmse_test))
# Out:
# Train set RMSE: 0.135382
# Test set RMSE: 0.369781

# %%
rf_params = {'max_depth': [6,7,8],'min_samples_leaf':[0.08,0.1,0.12], 'max_features':[0.5,0.7,0.9]}

from sklearn.model_selection import GridSearchCV
grid_rf = GridSearchCV(estimator = rf,
                     param_grid = rf_params,
                     cv=5,
                     scoring='neg_mean_squared_error',
                     verbose=2)

grid_rf.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV] END max_depth=6, max_features=0.5, min_samples_leaf=0.08; total time=   1.1s
# [CV] END max_depth=6, max_features=0.5, min_samples_leaf=0.08; total time=   1.1s
# [CV] END max_depth=6, max_features=0.5, min_samples_leaf=0.08; total time=   0.9s
# [CV] END max_depth=6, max_features=0.5, min_samples_leaf=0.08; total time=   0.8s
# [CV] END max_depth=6, max_features=0.5, min_samples_leaf=0.08; total time=   0.7s
# [CV] END max_depth=6, max_features=0.5, min_samples_leaf=0.1; total time=   0.6s
# [CV] END max_depth=6, max_features=0.5, min_samples_leaf=0.1; total time=   0.6s
# [CV] END max_depth=6, max_features=0.5, min_samples_leaf=0.1; total time=   0.5s
# [CV] END max_depth=6, max_features=0.5, min_samples_leaf=0.1; total time=   0.7s
# [CV] END max_depth=6, max_features=0.5, min_samples_leaf=0.1; total time=   0.7s
# [CV] END max_depth=6, max_features=0.5, min_samples_leaf=0.12; total time=   0.7s
# [CV] END max_depth=6, max_features=0.5, min_samples_leaf=0.12; total time=   0.9s
# [CV] END max_depth=6, max_features=0.5, min_samples_leaf=0.12; total time=   0.8s
# [CV] END max_depth=6, max_features=0.5, min_samples_leaf=0.12; total time=   0.9s
# [CV] END max_depth=6, max_features=0.5, min_samples_leaf=0.12; total time=   0.8s
# [CV] END max_depth=6, max_features=0.7, min_samples_leaf=0.08; total time=   0.8s
# [CV] END max_depth=6, max_features=0.7, min_samples_leaf=0.08; total time=   0.8s
# [CV] END max_depth=6, max_features=0.7, min_samples_leaf=0.08; total time=   0.8s
# [CV] END max_depth=6, max_features=0.7, min_samples_leaf=0.08; total time=   0.5s
# [CV] END max_depth=6, max_features=0.7, min_samples_leaf=0.08; total time=   0.7s
# [CV] END max_depth=6, max_features=0.7, min_samples_leaf=0.1; total time=   1.2s
# [CV] END max_depth=6, max_features=0.7, min_samples_leaf=0.1; total time=   0.7s
# [CV] END max_depth=6, max_features=0.7, min_samples_leaf=0.1; total time=   0.8s
# [CV] END max_depth=6, max_features=0.7, min_samples_leaf=0.1; total time=   0.4s
# [CV] END max_depth=6, max_features=0.7, min_samples_leaf=0.1; total time=   0.4s
# [CV] END max_depth=6, max_features=0.7, min_samples_leaf=0.12; total time=   0.4s
# [CV] END max_depth=6, max_features=0.7, min_samples_leaf=0.12; total time=   0.9s
# [CV] END max_depth=6, max_features=0.7, min_samples_leaf=0.12; total time=   0.5s
# [CV] END max_depth=6, max_features=0.7, min_samples_leaf=0.12; total time=   0.4s
# [CV] END max_depth=6, max_features=0.7, min_samples_leaf=0.12; total time=   0.4s
# [CV] END max_depth=6, max_features=0.9, min_samples_leaf=0.08; total time=   0.5s
# [CV] END max_depth=6, max_features=0.9, min_samples_leaf=0.08; total time=   0.4s
# [CV] END max_depth=6, max_features=0.9, min_samples_leaf=0.08; total time=   0.4s
# [CV] END max_depth=6, max_features=0.9, min_samples_leaf=0.08; total time=   0.5s
# [CV] END max_depth=6, max_features=0.9, min_samples_leaf=0.08; total time=   0.7s
# [CV] END max_depth=6, max_features=0.9, min_samples_leaf=0.1; total time=   0.7s
# [CV] END max_depth=6, max_features=0.9, min_samples_leaf=0.1; total time=   0.5s
# [CV] END max_depth=6, max_features=0.9, min_samples_leaf=0.1; total time=   0.5s
# [CV] END max_depth=6, max_features=0.9, min_samples_leaf=0.1; total time=   0.5s
# [CV] END max_depth=6, max_features=0.9, min_samples_leaf=0.1; total time=   0.4s
# [CV] END max_depth=6, max_features=0.9, min_samples_leaf=0.12; total time=   0.5s
# [CV] END max_depth=6, max_features=0.9, min_samples_leaf=0.12; total time=   0.9s
# [CV] END max_depth=6, max_features=0.9, min_samples_leaf=0.12; total time=   0.9s
# [CV] END max_depth=6, max_features=0.9, min_samples_leaf=0.12; total time=   0.8s
# [CV] END max_depth=6, max_features=0.9, min_samples_leaf=0.12; total time=   0.5s
# [CV] END max_depth=7, max_features=0.5, min_samples_leaf=0.08; total time=   0.3s
# [CV] END max_depth=7, max_features=0.5, min_samples_leaf=0.08; total time=   0.4s
# [CV] END max_depth=7, max_features=0.5, min_samples_leaf=0.08; total time=   0.6s
# [CV] END max_depth=7, max_features=0.5, min_samples_leaf=0.08; total time=   1.0s
# [CV] END max_depth=7, max_features=0.5, min_samples_leaf=0.08; total time=   0.7s
# [CV] END max_depth=7, max_features=0.5, min_samples_leaf=0.1; total time=   0.5s
# [CV] END max_depth=7, max_features=0.5, min_samples_leaf=0.1; total time=   0.3s
# [CV] END max_depth=7, max_features=0.5, min_samples_leaf=0.1; total time=   0.3s
# [CV] END max_depth=7, max_features=0.5, min_samples_leaf=0.1; total time=   0.5s
# [CV] END max_depth=7, max_features=0.5, min_samples_leaf=0.1; total time=   0.5s
# [CV] END max_depth=7, max_features=0.5, min_samples_leaf=0.12; total time=   0.7s
# [CV] END max_depth=7, max_features=0.5, min_samples_leaf=0.12; total time=   0.5s
# [CV] END max_depth=7, max_features=0.5, min_samples_leaf=0.12; total time=   1.1s
# [CV] END max_depth=7, max_features=0.5, min_samples_leaf=0.12; total time=   1.2s
# [CV] END max_depth=7, max_features=0.5, min_samples_leaf=0.12; total time=   1.4s
# [CV] END max_depth=7, max_features=0.7, min_samples_leaf=0.08; total time=   1.2s
# [CV] END max_depth=7, max_features=0.7, min_samples_leaf=0.08; total time=   0.4s
# [CV] END max_depth=7, max_features=0.7, min_samples_leaf=0.08; total time=   0.3s
# [CV] END max_depth=7, max_features=0.7, min_samples_leaf=0.08; total time=   0.2s
# [CV] END max_depth=7, max_features=0.7, min_samples_leaf=0.08; total time=   0.3s
# [CV] END max_depth=7, max_features=0.7, min_samples_leaf=0.1; total time=   0.2s
# [CV] END max_depth=7, max_features=0.7, min_samples_leaf=0.1; total time=   0.2s
# [CV] END max_depth=7, max_features=0.7, min_samples_leaf=0.1; total time=   0.2s
# [CV] END max_depth=7, max_features=0.7, min_samples_leaf=0.1; total time=   0.3s
# [CV] END max_depth=7, max_features=0.7, min_samples_leaf=0.1; total time=   0.2s
# [CV] END max_depth=7, max_features=0.7, min_samples_leaf=0.12; total time=   0.2s
# [CV] END max_depth=7, max_features=0.7, min_samples_leaf=0.12; total time=   0.3s
# [CV] END max_depth=7, max_features=0.7, min_samples_leaf=0.12; total time=   0.3s
# [CV] END max_depth=7, max_features=0.7, min_samples_leaf=0.12; total time=   0.4s
# [CV] END max_depth=7, max_features=0.7, min_samples_leaf=0.12; total time=   0.3s
# [CV] END max_depth=7, max_features=0.9, min_samples_leaf=0.08; total time=   0.5s
# [CV] END max_depth=7, max_features=0.9, min_samples_leaf=0.08; total time=   0.8s
# [CV] END max_depth=7, max_features=0.9, min_samples_leaf=0.08; total time=   0.8s
# [CV] END max_depth=7, max_features=0.9, min_samples_leaf=0.08; total time=   0.8s
# [CV] END max_depth=7, max_features=0.9, min_samples_leaf=0.08; total time=   0.5s
# [CV] END max_depth=7, max_features=0.9, min_samples_leaf=0.1; total time=   0.3s
# [CV] END max_depth=7, max_features=0.9, min_samples_leaf=0.1; total time=   0.3s
# [CV] END max_depth=7, max_features=0.9, min_samples_leaf=0.1; total time=   0.3s
# [CV] END max_depth=7, max_features=0.9, min_samples_leaf=0.1; total time=   0.3s
# [CV] END max_depth=7, max_features=0.9, min_samples_leaf=0.1; total time=   0.2s
# [CV] END max_depth=7, max_features=0.9, min_samples_leaf=0.12; total time=   0.2s
# [CV] END max_depth=7, max_features=0.9, min_samples_leaf=0.12; total time=   0.2s
# [CV] END max_depth=7, max_features=0.9, min_samples_leaf=0.12; total time=   0.2s
# [CV] END max_depth=7, max_features=0.9, min_samples_leaf=0.12; total time=   0.2s
# [CV] END max_depth=7, max_features=0.9, min_samples_leaf=0.12; total time=   0.2s
# [CV] END max_depth=8, max_features=0.5, min_samples_leaf=0.08; total time=   0.2s
# [CV] END max_depth=8, max_features=0.5, min_samples_leaf=0.08; total time=   0.2s
# [CV] END max_depth=8, max_features=0.5, min_samples_leaf=0.08; total time=   0.2s
# [CV] END max_depth=8, max_features=0.5, min_samples_leaf=0.08; total time=   0.2s
# [CV] END max_depth=8, max_features=0.5, min_samples_leaf=0.08; total time=   0.3s
# [CV] END max_depth=8, max_features=0.5, min_samples_leaf=0.1; total time=   0.3s
# [CV] END max_depth=8, max_features=0.5, min_samples_leaf=0.1; total time=   0.3s
# [CV] END max_depth=8, max_features=0.5, min_samples_leaf=0.1; total time=   0.3s
# [CV] END max_depth=8, max_features=0.5, min_samples_leaf=0.1; total time=   0.6s
# [CV] END max_depth=8, max_features=0.5, min_samples_leaf=0.1; total time=   0.7s
# [CV] END max_depth=8, max_features=0.5, min_samples_leaf=0.12; total time=   0.8s
# [CV] END max_depth=8, max_features=0.5, min_samples_leaf=0.12; total time=   0.7s
# [CV] END max_depth=8, max_features=0.5, min_samples_leaf=0.12; total time=   0.3s
# [CV] END max_depth=8, max_features=0.5, min_samples_leaf=0.12; total time=   0.2s
# [CV] END max_depth=8, max_features=0.5, min_samples_leaf=0.12; total time=   0.2s
# [CV] END max_depth=8, max_features=0.7, min_samples_leaf=0.08; total time=   0.2s
# [CV] END max_depth=8, max_features=0.7, min_samples_leaf=0.08; total time=   0.2s
# [CV] END max_depth=8, max_features=0.7, min_samples_leaf=0.08; total time=   0.2s
# [CV] END max_depth=8, max_features=0.7, min_samples_leaf=0.08; total time=   0.2s
# [CV] END max_depth=8, max_features=0.7, min_samples_leaf=0.08; total time=   0.3s
# [CV] END max_depth=8, max_features=0.7, min_samples_leaf=0.1; total time=   0.2s
# [CV] END max_depth=8, max_features=0.7, min_samples_leaf=0.1; total time=   0.2s
# [CV] END max_depth=8, max_features=0.7, min_samples_leaf=0.1; total time=   0.3s
# [CV] END max_depth=8, max_features=0.7, min_samples_leaf=0.1; total time=   0.2s
# [CV] END max_depth=8, max_features=0.7, min_samples_leaf=0.1; total time=   0.2s
# [CV] END max_depth=8, max_features=0.7, min_samples_leaf=0.12; total time=   0.2s
# [CV] END max_depth=8, max_features=0.7, min_samples_leaf=0.12; total time=   0.2s
# [CV] END max_depth=8, max_features=0.7, min_samples_leaf=0.12; total time=   0.2s
# [CV] END max_depth=8, max_features=0.7, min_samples_leaf=0.12; total time=   0.2s
# [CV] END max_depth=8, max_features=0.7, min_samples_leaf=0.12; total time=   0.2s
# [CV] END max_depth=8, max_features=0.9, min_samples_leaf=0.08; total time=   0.4s
# [CV] END max_depth=8, max_features=0.9, min_samples_leaf=0.08; total time=   0.3s
# [CV] END max_depth=8, max_features=0.9, min_samples_leaf=0.08; total time=   0.3s
# [CV] END max_depth=8, max_features=0.9, min_samples_leaf=0.08; total time=   0.4s
# [CV] END max_depth=8, max_features=0.9, min_samples_leaf=0.08; total time=   0.6s
# [CV] END max_depth=8, max_features=0.9, min_samples_leaf=0.1; total time=   0.9s
# [CV] END max_depth=8, max_features=0.9, min_samples_leaf=0.1; total time=   0.8s
# [CV] END max_depth=8, max_features=0.9, min_samples_leaf=0.1; total time=   0.8s
# [CV] END max_depth=8, max_features=0.9, min_samples_leaf=0.1; total time=   0.4s
# [CV] END max_depth=8, max_features=0.9, min_samples_leaf=0.1; total time=   0.3s
# [CV] END max_depth=8, max_features=0.9, min_samples_leaf=0.12; total time=   0.3s
# [CV] END max_depth=8, max_features=0.9, min_samples_leaf=0.12; total time=   0.3s
# [CV] END max_depth=8, max_features=0.9, min_samples_leaf=0.12; total time=   0.4s
# [CV] END max_depth=8, max_features=0.9, min_samples_leaf=0.12; total time=   0.5s
# [CV] END max_depth=8, max_features=0.9, min_samples_leaf=0.12; total time=   0.3s
# GridSearchCV(cv=5,
#              estimator=RandomForestRegressor(n_estimators=200,
#                                              random_state=123),
#              param_grid={'max_depth': [6, 7, 8],
#                          'max_features': [0.5, 0.7, 0.9],
#                          'min_samples_leaf': [0.08, 0.1, 0.12]},
#              scoring='neg_mean_squared_error', verbose=2)

# %%
best_param = grid_rf.best_params_
print('Best parameters found for rf: ', best_param)
print('Lowerst RMSE found for rf: ', np.sqrt(np.sqrt(np.abs(grid_rf.best_score_))))
# Out:
# Best parameters found for rf:  {'max_depth': 6, 'max_features': 0.7, 'min_samples_leaf': 0.12}
# Lowerst RMSE found for rf:  0.6018365609626789

# %%
from sklearn.model_selection import GridSearchCV
grid_rf = RandomForestRegressor(n_estimators = 200, random_state=123, **best_param, verbose=1)

grid_rf.fit(x_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.1s
# RandomForestRegressor(max_depth=6, max_features=0.7, min_samples_leaf=0.12,
#                       n_estimators=200, random_state=123, verbose=1)

# %%
# predictions
rf_pred_tr = grid_rf.predict(x_train)
rf_pred_ts = grid_rf.predict(x_test)
rmse_train = mean_squared_error(y_train, rf_pred_tr)**(1/2)
rmse_test = mean_squared_error(y_test, rf_pred_ts)**(1/2)
print("Train set RMSE: %f " % (rmse_train))
print("Test set RMSE: %f " % (rmse_test))
# Out:
# Train set RMSE: 0.284251
# Test set RMSE: 0.373196
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.0s

# %%
plt.figure(figsize=(8,6))
importances = grid_rf.feature_importances_
indices = np.argsort(importances)[::-1]
plt.bar(x_train.columns[indices], importances[indices]) 
plt.title('Feature Importance', fontsize=16);

# %%
import xgboost as xgb

# Create DMatrix for Cross Validation: an optimized & compressed matrix used to store the datasets optimally in xgboost
# It is very recommendable 
data_dmatrix = xgb.DMatrix(data=x, label=y)

xg_reg = xgb.XGBRegressor(objective = 'reg:squarederror', n_estimators = 20)
xg_reg.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=20, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
preds = xg_reg.predict(x_train)
preds_test = xg_reg.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_train, preds))
rmse_test = np.sqrt(mean_squared_error(y_test, preds_test))
print("Attempt 1 Train RMSE: %f" % (rmse))
print("Attmept 1 Test RMSE: %f" % (rmse_test))
# Out:
# Attempt 1 Train RMSE: 0.004182
# Attmept 1 Test RMSE: 0.387054

# %%
params = {'objective':'reg:squarederror', 'colsample_bytree':0.3, 'learning_rate':0.1, 'max_depth':5,
         'alpha':10}

cv_results = xgb.cv(dtrain=data_dmatrix, params=params, nfold = 3, num_boost_round=200, early_stopping_rounds=5,
                   metrics="rmse", as_pandas=True, seed=123)

# num_boost_round: rounds. A high value might lead to overfitting
# early_stopping_rounds: if the evaluation metric does not improve in this number of consecutive rounds, training stops. Risk of overfitting if empty
# as_pandas=True: predictions will be returned as a dataframe, instead of a dictionary
cv_results
# Out:
#     train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0          0.481198        0.001585        0.490030       0.002133
# 1          0.464857        0.002378        0.476249       0.002210
# 2          0.453755        0.002528        0.469082       0.002136
# 3          0.441174        0.003115        0.460446       0.002236
# 4          0.430040        0.003936        0.452003       0.001911
# 5          0.420440        0.006009        0.446332       0.001953
# 6          0.409825        0.006791        0.437985       0.002070
# 7          0.400542        0.007364        0.431715       0.001867
# 8          0.393814        0.007527        0.427816       0.002543
# 9          0.385527        0.007714        0.421884       0.003111
# 10         0.378174        0.007445        0.416632       0.003639
# 11         0.373813        0.008473        0.414106       0.004201
# 12         0.367313        0.008981        0.410313       0.004314
# 13         0.360996        0.008276        0.406297       0.005115
# 14         0.355658        0.008371        0.403069       0.005753
# 15         0.351427        0.008660        0.400508       0.006058
# 16         0.347352        0.008796        0.398344       0.006118
# 17         0.343324        0.008802        0.395967       0.006758
# 18         0.340496        0.009076        0.393905       0.007017
# 19         0.336362        0.009364        0.391398       0.007374
# 20         0.333429        0.009662        0.390436       0.007316
# 21         0.331613        0.011001        0.389431       0.006676
# 22         0.331054        0.011312        0.389170       0.006406
# 23         0.329525        0.012428        0.388527       0.005942
# 24         0.329525        0.012428        0.388527       0.005942
# 25         0.329525        0.012428        0.388527       0.005942
# 26         0.328902        0.012807        0.388293       0.005708
# 27         0.327981        0.013454        0.388045       0.005470
# 28         0.327111        0.014070        0.387775       0.005360
# 29         0.327111        0.014070        0.387775       0.005360
# 30         0.327111        0.014070        0.387775       0.005360
# 31         0.327111        0.014070        0.387775       0.005360
# 32         0.326573        0.014441        0.387566       0.005155
# 33         0.326573        0.014441        0.387566       0.005155
# 34         0.326573        0.014441        0.387566       0.005155
# 35         0.326573        0.014441        0.387566       0.005155
# 36         0.325917        0.014932        0.387311       0.004916

# %%
print((cv_results['test-rmse-mean']).tail(5))
# Out:
# 32    0.387566
# 33    0.387566
# 34    0.387566
# 35    0.387566
# 36    0.387311
# Name: test-rmse-mean, dtype: float64

# %%
gbm_param_grid = {'learning_rate': [0.01, 0.1, 0.2], 'subsample':[0.3,0.4,0.5]} #subsample controls % of data used
gbm = xgb.XGBRegressor()

grid_mse = GridSearchCV(estimator=gbm, param_grid=gbm_param_grid, scoring='neg_mean_squared_error', cv=5, verbose=2)
grid_mse.fit(x, y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END ..................learning_rate=0.01, subsample=0.3; total time=   0.3s
# [CV] END ..................learning_rate=0.01, subsample=0.3; total time=   0.5s
# [CV] END ..................learning_rate=0.01, subsample=0.3; total time=   0.5s
# [CV] END ..................learning_rate=0.01, subsample=0.3; total time=   0.4s
# [CV] END ..................learning_rate=0.01, subsample=0.3; total time=   0.4s
# [CV] END ..................learning_rate=0.01, subsample=0.4; total time=   0.4s
# [CV] END ..................learning_rate=0.01, subsample=0.4; total time=   0.4s
# [CV] END ..................learning_rate=0.01, subsample=0.4; total time=   0.4s
# [CV] END ..................learning_rate=0.01, subsample=0.4; total time=   0.4s
# [CV] END ..................learning_rate=0.01, subsample=0.4; total time=   0.4s
# [CV] END ..................learning_rate=0.01, subsample=0.5; total time=   0.5s
# [CV] END ..................learning_rate=0.01, subsample=0.5; total time=   0.6s
# [CV] END ..................learning_rate=0.01, subsample=0.5; total time=   0.5s
# [CV] END ..................learning_rate=0.01, subsample=0.5; total time=   0.5s
# [CV] END ..................learning_rate=0.01, subsample=0.5; total time=   0.5s
# [CV] END ...................learning_rate=0.1, subsample=0.3; total time=   1.2s
# [CV] END ...................learning_rate=0.1, subsample=0.3; total time=   1.4s
# [CV] END ...................learning_rate=0.1, subsample=0.3; total time=   0.9s
# [CV] END ...................learning_rate=0.1, subsample=0.3; total time=   0.8s
# [CV] END ...................learning_rate=0.1, subsample=0.3; total time=   0.9s
# [CV] END ...................learning_rate=0.1, subsample=0.4; total time=   0.7s
# [CV] END ...................learning_rate=0.1, subsample=0.4; total time=   0.7s
# [CV] END ...................learning_rate=0.1, subsample=0.4; total time=   0.6s
# [CV] END ...................learning_rate=0.1, subsample=0.4; total time=   0.7s
# [CV] END ...................learning_rate=0.1, subsample=0.4; total time=   0.7s
# [CV] END ...................learning_rate=0.1, subsample=0.5; total time=   0.6s
# [CV] END ...................learning_rate=0.1, subsample=0.5; total time=   0.6s
# [CV] END ...................learning_rate=0.1, subsample=0.5; total time=   0.7s
# [CV] END ...................learning_rate=0.1, subsample=0.5; total time=   0.8s
# [CV] END ...................learning_rate=0.1, subsample=0.5; total time=   0.7s
# [CV] END ...................learning_rate=0.2, subsample=0.3; total time=   1.0s
# [CV] END ...................learning_rate=0.2, subsample=0.3; total time=   0.5s
# [CV] END ...................learning_rate=0.2, subsample=0.3; total time=   0.5s
# [CV] END ...................learning_rate=0.2, subsample=0.3; total time=   0.5s
# [CV] END ...................learning_rate=0.2, subsample=0.3; total time=   0.6s
# [CV] END ...................learning_rate=0.2, subsample=0.4; total time=   0.6s
# [CV] END ...................learning_rate=0.2, subsample=0.4; total time=   0.6s
# [CV] END ...................learning_rate=0.2, subsample=0.4; total time=   0.8s
# [CV] END ...................learning_rate=0.2, subsample=0.4; total time=   0.6s
# [CV] END ...................learning_rate=0.2, subsample=0.4; total time=   0.7s
# [CV] END ...................learning_rate=0.2, subsample=0.5; total time=   0.6s
# [CV] END ...................learning_rate=0.2, subsample=0.5; total time=   0.7s
# [CV] END ...................learning_rate=0.2, subsample=0.5; total time=   0.6s
# [CV] END ...................learning_rate=0.2, subsample=0.5; total time=   0.6s
# [CV] END ...................learning_rate=0.2, subsample=0.5; total time=   0.8s
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'subsample': [0.3, 0.4, 0.5]},
#              scoring='neg_mean_squared_error', verbose=2)

# %%
#Print best performing parameters and their RMSE scores
print('Best parameters found: ', grid_mse.best_params_)
print('Lowest RMSE found: ', np.sqrt(np.sqrt(np.abs(grid_mse.best_score_))))
# Out:
# Best parameters found:  {'learning_rate': 0.1, 'subsample': 0.5}
# Lowest RMSE found:  0.6356261089799832

# %%
xgb.plot_importance(xg_reg, importance_type="weight")

# weight: number of times the variable has been used
# gain: average gain whenever variable is used
# cover: how many samples were affected by using each variable
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# Bagging + Random Forest Models

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import waterfall_chart

from fastai.imports import *
from fastai.tabular import *
from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from IPython.display import display

from sklearn import metrics
from sklearn.datasets import load_breast_cancer
from sklearn.metrics import roc_curve, roc_auc_score, accuracy_score, precision_recall_curve, confusion_matrix, recall_score, precision_score
from sklearn.model_selection import cross_val_score
from matplotlib.ticker import FuncFormatter

# %%
data = pd.read_csv('../DATA/GlaucomaM.csv')
data.head()
# Out:
#       ag     at     as     an     ai    eag    eat    eas    ean    eai  ...  \
# 0  2.220  0.354  0.580  0.686  0.601  1.267  0.336  0.346  0.255  0.331  ...
# 1  2.681  0.475  0.672  0.868  0.667  2.053  0.440  0.520  0.639  0.454  ...
# 2  1.979  0.343  0.508  0.624  0.504  1.200  0.299  0.396  0.259  0.246  ...
# 3  1.747  0.269  0.476  0.525  0.476  0.612  0.147  0.017  0.044  0.405  ...
# 4  2.990  0.599  0.686  1.039  0.667  2.513  0.543  0.607  0.871  0.492  ...
#
#      tmt    tms    tmn    tmi     mr    rnf   mdic    emd     mv   Class
# 0 -0.018 -0.230 -0.510 -0.158  0.841  0.410  0.137  0.239  0.035  normal
# 1 -0.014 -0.165 -0.317 -0.192  0.924  0.256  0.252  0.329  0.022  normal
# 2 -0.097 -0.235 -0.337 -0.020  0.795  0.378  0.152  0.250  0.029  normal
# 3 -0.035 -0.449 -0.217 -0.091  0.746  0.200  0.027  0.078  0.023  normal
# 4 -0.105  0.084 -0.012 -0.054  0.977  0.193  0.297  0.354  0.034  normal
#
# [5 rows x 63 columns]

# %%
data['Class'] = data['Class'].map({'glaucoma': 1, 'normal': 0})

# %%
unique, counts = np.unique(data["Class"], return_counts=True)
plt.pie(counts, labels=unique, autopct='%.0f%%');

# %%
#split data into train and test set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data.iloc[:,data.columns != 'Class'],
                                                    data['Class'],
                                                    test_size=0.25, 
                                                    random_state=100)

# %%
print("Train: ", x_train.shape)
print("Test: ", x_test.shape)
# Out:
# Train:  (147, 62)
# Test:  (49, 62)

# %%
baseRF = RandomForestClassifier(n_estimators = 200,  # The number of trees in the forest
                               random_state = 0, # This parameter allows to replicate results
                               n_jobs = -1, # The number of jobs to run in parallel (-1 means all processors, 1 no parallelism)
                               oob_score = True) # Whether to use out-of-bag samples to estimate the generalization score (increases time)

# The OOB score is an estimate of the generalization error of the model, calculated with the data not used to train it.
# Since each tree is trained on a bootstrapped sample, they all use approximately 2/3 of the data (this is a mathematical consequence 
# of random sampling with replacement). Therefore, for each of the learners we have 1/3 of the dataset as Out Of Bag (OOB) observations 
# which can be used to test the model and estimate its generalisation error. By averaging these OOB error estimates across the trees, 
# RF produces a robust error estimate for the ensemble during training time at almost no additional computational cost.

# other parameters:
# criterion{"gini", "entropy", "log_loss"}, default="gini"
# max_depth: int, default=None
# min_samples_leaf: int or float, default=1 - The minimum number of samples required to be at a leaf node
# min_samples_split: int or float, default=2 - The minimum number of samples required to split an internal node:
# max_features{"sqrt", "log2", None}, int or float, default="sqrt" - The number of features to consider when looking for the best split

baseRF.fit(x_train,y_train)

# predictions
y_pred_test = baseRF.predict(x_test)

print("OOB score: {:.2%}".format(baseRF.oob_score_))
# Out:
# OOB score: 82.99%

# %%
param_grid = {
    'min_samples_leaf' :[1,3,5], 
    'max_features' : [10,15,20,25,30],
    'criterion' : ['gini','entropy'] #,'log_loss']
}

# %%
import time 
start_time = time.time()

from sklearn.model_selection import GridSearchCV
cvRF = GridSearchCV(estimator=baseRF, param_grid=param_grid, cv=5, scoring='roc_auc') 
#cv is the number of cross validation iterations to be performed
cvRF.fit(x_train,y_train)

print ("Completed in {:0.0f} seconds ".format((time.time() - start_time)))
# Out:
# Completed in 166 seconds

# %%
# shows the best combination of criteria found
best_params = cvRF.best_params_
print("Best parameters:", best_params)
# Out:
# Best parameters: {'criterion': 'gini', 'max_features': 10, 'min_samples_leaf': 1}

# %%
# shows the best score (of the scoring function we selected, here ROC AUC) from TRAINING DATASET
print("ROC AUC: ", '{0:0.2%}'.format(cvRF.best_score_))
# Out:
# ROC AUC:  91.63%

# %%
# Random Forest
model_RF = RandomForestClassifier(n_estimators = 200, 
                               random_state = 0,
                               max_features = 30, #this parameter makes the difference between simple Bagging and Random Forests
                               n_jobs = -1,
                               oob_score = True,
                               # criterion = 'entropy',
                               min_samples_leaf = 5)
model_RF.fit(x_train,y_train)

# predictions
y_pred_test = model_RF.predict(x_test)

# %%
print("OOB score: {:.2%}".format(model_RF.oob_score_))
# Out:
# OOB score: 82.31%

# %%
pred_prob = model_RF.predict_proba(x_test) #probability of being in both groups
prob_malign = [p[1] for p in pred_prob] #probability of being in the malign group
auc = roc_auc_score(y_test, prob_malign)

print("ROC AUC score: {:.2%}".format(auc))
# Out:
# ROC AUC score: 92.42%

# %%
# AUC Calculations - false positive rates, true positive rates and thresholds
fpr, tpr, thresholds = metrics.roc_curve(y_test, prob_malign, pos_label=1)

train_acc = round(model_RF.score(x_train,y_train) * 100,2) #Train Accuracy score
test_acc = round(model_RF.score(x_test,y_test) * 100,2) #Test Accuracy score
print("Train Accuracy score: ", train_acc, "%")
print("Test Accuracy score: ", test_acc, "%")
# Out:
# Train Accuracy score:  93.88 %
# Test Accuracy score:  87.76 %

# %%
# ROC curve

fig, ax = plt.subplots(1, 1)
ax.plot(fpr, tpr, label="ROC")
ax.plot([0, 1], [0, 1],linestyle='--', label="Random model") 
ax.set_xlabel("FPR")
ax.set_ylabel("TPR")
ax.set_box_aspect(1)
ax.legend()
plt.show()

# %%
# We can compare Recall and Precision

prob_pred = model_RF.predict_proba(x_test)[:, 1]
thresholds = np.arange(0.0, 1.0, step=0.01)
recall_scores = [metrics.recall_score(y_test, prob_pred > t) for t in thresholds]
precis_scores = [metrics.precision_score(y_test, prob_pred > t) for t in thresholds]
fig, ax = plt.subplots(1, 1)
ax.plot(thresholds, recall_scores, label="Recall @ t")
ax.plot(thresholds, precis_scores, label="Precision @ t")
ax.axvline(0.5, c="gray", linestyle="--", label="Default Threshold")
ax.set_xlabel("Threshold")
ax.set_ylabel("Metric @ Threshold")
ax.set_box_aspect(1)
ax.legend()
plt.show()
# Out:
# c:\Users\SLO\Documents\GitHub\IE-University\myenv312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
importances = model_RF.feature_importances_

indexes = np.argsort(importances)[::-1]
sorted_imp = importances[indexes]

plt.figure(figsize=(12, 6))
bars = plt.bar(range(len(importances)), importances[indexes], align='center')
plt.xticks(range(len(importances)), np.array(model_RF.feature_names_in_)[indexes], rotation=90)
plt.xlabel("Features")
plt.ylabel("Importance")
plt.xticks(rotation=90, fontsize=8)
plt.title("Relative feature importances (from 0 to 1)")
for i, bar in enumerate(bars):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
             f'{sorted_imp[i]:.2f}', ha='center', va='bottom')
plt.show()
