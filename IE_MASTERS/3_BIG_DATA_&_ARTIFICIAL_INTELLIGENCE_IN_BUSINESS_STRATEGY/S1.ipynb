# %% [markdown]
# ### Course Presentation

# %% [markdown]
# Introductory Business Course
# - Learn how to take advantage of business opportunities presented by AI and Big Data
# - Not technical
# - Case Studies, Articles, Demos, etc

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Introduction to Big Data

# %% [markdown]
# ### Introduction to AI
